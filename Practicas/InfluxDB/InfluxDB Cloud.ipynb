# %% [markdown]
# # Requisitos
#    * pip install influxdb-client

# %%
from time import sleep
from datetime import datetime
from influxdb_client.client.write_api import SYNCHRONOUS
from influxdb_client import InfluxDBClient, Point, WritePrecision

myBucket = ""
myOrg = ""
myUrl = ""
myToken = ""

client = InfluxDBClient(url=myUrl, token=myToken, org=myOrg)

write_api = client.write_api(write_options=SYNCHRONOUS)
query_api = client.query_api()

# %%
p0 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.3).field("internalTemp", 63).field("externalTemp", 50).time(datetime.utcnow(), WritePrecision.NS)

sleep(60)

p1 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.3).field("internalTemp", 63).field("externalTemp", 52).time(datetime.utcnow(), WritePrecision.NS)
    
sleep(60)
    
p2 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.271).field("internalTemp", 61).field("externalTemp", 54).time(datetime.utcnow(), WritePrecision.NS)
    
sleep(60)
    
p3 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.3).field("internalTemp", 63.5).field("externalTemp", 55).time(datetime.utcnow(), WritePrecision.NS)

sleep(60)

p4 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.3).field("internalTemp", 63).field("externalTemp", 53).time(datetime.utcnow(), WritePrecision.NS)

sleep(60)

p5 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.3).field("internalTemp", 63).field("externalTemp", 52).time(datetime.utcnow(), WritePrecision.NS)

sleep(60)

p6 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.3).field("internalTemp", 63).field("externalTemp", 51).time(datetime.utcnow(), WritePrecision.NS)

sleep(60)

p7 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.271).field("internalTemp", 62.74).field("externalTemp", 50).time(datetime.utcnow(), WritePrecision.NS)

sleep(60)

p8 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.399).field("internalTemp", 63).field("externalTemp", 50).time(datetime.utcnow(), WritePrecision.NS)

sleep(60)

p9 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.42).field("internalTemp", 63.8).field("externalTemp", 51).time(datetime.utcnow(), WritePrecision.NS)

sleep(60)

p10 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.2).field("internalTemp", 62.6).field("externalTemp", 51).time(datetime.utcnow(), WritePrecision.NS)

sleep(5)

p11 = Point("cpu").tag("place1", "mother board").tag("place2","socket").tag("component","processor")\
.field("volts", 3.3).field("internalTemp", 63).field("externalTemp", 51).time(datetime.utcnow(), WritePrecision.NS)

sleep(5)

write_api.write(bucket=myBucket, record=[p0,p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11])

# %%
#.get_field()
#.get_value()
#.values.get(“<your tags>”)
#.get_time()
#.get_start()
#.get_stop()
#.get_measurement()

tables = query_api.query('from(bucket:"Main") |> range(start: -24h)')

for table in tables:
    for row in table.records:
        print((row.get_value(), row.get_field()))
# Out:
# (63, 'internalTemp')
# (63, 'internalTemp')
# (61, 'internalTemp')
# (63, 'internalTemp')
# (63, 'internalTemp')
# (63, 'internalTemp')
# (63, 'internalTemp')
# (63, 'internalTemp')
# (50, 'externalTemp')
# (52, 'externalTemp')
# (54, 'externalTemp')
# (55, 'externalTemp')
# (53, 'externalTemp')
# (52, 'externalTemp')
# (51, 'externalTemp')
# (50, 'externalTemp')
# (50, 'externalTemp')
# (51, 'externalTemp')
# (51, 'externalTemp')
# (51, 'externalTemp')
# (3.3, 'volts')
# (3.3, 'volts')
# (3.271, 'volts')
# (3.3, 'volts')
# (3.3, 'volts')
# (3.3, 'volts')
# (3.3, 'volts')
# (3.271, 'volts')
# (3.399, 'volts')
# (3.42, 'volts')
# (3.2, 'volts')
# (3.3, 'volts')

# %%
records = query_api.query_stream('from(bucket:"Main") |> range(start: -24h)')

for record in records:
    print(record,"\n\n")

records.close()
# Out:
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2020, 5, 11, 23, 16, 16, 229792, tzinfo=datetime.timezone.utc), '_stop': datetime.datetime(2020, 5, 12, 23, 16, 16, 229792, tzinfo=datetime.timezone.utc), '_time': datetime.datetime(2020, 5, 12, 23, 6, 4, 685007, tzinfo=datetime.timezone.utc), '_value': 63, '_field': 'internalTemp', '_measurement': 'cpu', 'component': 'processor', 'place1': 'mother board', 'place2': 'socket'}
#
#
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2020, 5, 11, 23, 16, 16, 229792, tzinfo=datetime.timezone.utc), '_stop': datetime.datetime(2020, 5, 12, 23, 16, 16, 229792, tzinfo=datetime.timezone.utc), '_time': datetime.datetime(2020, 5, 12, 23, 7, 4, 745764, tzinfo=datetime.timezone.utc), '_value': 63, '_field': 'internalTemp', '_measurement': 'cpu', 'component': 'processor', 'place1': 'mother board', 'place2': 'socket'}
#
#
# ...

# %%
data_frame = query_api.query_data_frame('from(bucket:"Main") |> range(start: -24h)')

print(data_frame[0])
# Out:
#      result table                            _start  \
# 0   _result     0  2020-05-11 23:16:16.537208+00:00
# 1   _result     0  2020-05-11 23:16:16.537208+00:00
# 2   _result     0  2020-05-11 23:16:16.537208+00:00
# 3   _result     0  2020-05-11 23:16:16.537208+00:00
# 4   _result     0  2020-05-11 23:16:16.537208+00:00
# 5   _result     0  2020-05-11 23:16:16.537208+00:00
# 6   _result     0  2020-05-11 23:16:16.537208+00:00
# 7   _result     0  2020-05-11 23:16:16.537208+00:00
# 8   _result     0  2020-05-11 23:16:16.537208+00:00
# 9   _result     0  2020-05-11 23:16:16.537208+00:00
# 10  _result     0  2020-05-11 23:16:16.537208+00:00
# 11  _result     0  2020-05-11 23:16:16.537208+00:00
#
#                                _stop                             _time _value  \
# 0   2020-05-12 23:16:16.537208+00:00  2020-05-12 23:06:04.685007+00:00     50
# 1   2020-05-12 23:16:16.537208+00:00  2020-05-12 23:07:04.745764+00:00     52
# ...

# %%
client.close();
