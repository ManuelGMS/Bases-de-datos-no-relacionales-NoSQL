# %% [markdown]
# # Mongo desde Python

# %% [markdown]
# Para una introducción al uso de Mongo desde Python, ver:
#
# [http://api.mongodb.com/python/current/tutorial.html]
#
# Aquí solo vamos a ver unos pocos ejemplos con dos ficheros json de comentarios de un foro. El primer fichero, usuarios.json, tiene los usuarios, que tienen un identificador y un *nick*. El segundo tiene los comentarios. Nos gustaría añadir el nick a cada comentario, sabiendo que el campo "content.authorId" ya contiene el identificador, lo que nos permitirá cruzar ambos ficheros.
#
# Ya en Python, empezamos por importar la librería que permite cargar datos desde mongo

# %%
import pymongo  # la conexión con mongo
from pprint import pprint

# %%
from pymongo import MongoClient
# cliente = MongoClient('mongodb://127.0.0.0:27017');
cliente = MongoClient();

# %% [markdown]
# Empezamos por acceder a la base de datos. Lo hacemos a través del cliente.

# %%
# db = client.pruebas
db = cliente.test;

# %% [markdown]
# Un insert de prueba

# %%
import datetime
queja = {"name": "Herminia",
         "level": 5,
         "tags": ["mongodb", "python", "pymongo"],
         "date": datetime.datetime.utcnow(),
         "comment": "Mongo casca con error 121"}

db.quejas.drop() # Ojo, esto borra completamente la colección
db.quejas.insert_one(queja)

# %% [markdown]
# Comprobamos que se ha creado listando las colecciones en la BD

# %%
colecciones = db.list_collection_names()
print(colecciones)
# Out:
# ['quejas', 'Empleados', 'compras']

# %% [markdown]
# Veamos cuantos elementos tiene cada coleccion

# %%
for col in colecciones:
    print(col,db[col].count_documents({}))
# Out:
# quejas 1
# Empleados 40
# compras 1000

# %%
unaqueja = db.quejas.find_one() # el primer usuario
pprint(unaqueja)
# Out:
# {'_id': ObjectId('5e3307409ac07687a578cdc4'),
#  'comment': 'Mongo casca con error 121',
#  'date': datetime.datetime(2020, 1, 30, 16, 41, 36, 571000),
#  'level': 5,
#  'name': 'Herminia',
#  'tags': ['mongodb', 'python', 'pymongo']}

# %% [markdown]
# Vamos a crear una colección con datos aleatorios

# %%
import random
import datetime
nombres = ['bertoldo','herminia','aniceto','calixta','melibea']

total = 1000 # total de usuarios a añadir

l = []
db.compras.drop()
for i in range(total):
    nombre= random.choice(nombres)+"_"+str(i)    
    edad = random.randint(1,101)
    totalcompras = random.randint(0,21)
    compras = []
    for j in range(totalcompras):
        compras.append(random.randint(1,200))
    dato = {"_id":i,"nombre": nombre, "edad":edad,"precios":compras, 
             "dir":{"calle":"rosa "+str(i %10), "num":str(i+len(compras)%50)},
             "hora":datetime.datetime.utcnow()}
    l.append(dato)
db.compras.insert_many(l)
print("Insertados ",db.compras.count_documents({}), " documentos")
# Out:
# Insertados  1000  documentos

# %% [markdown]
# Para que vaya más rápido podemos crear un índice

# %%
db.compras.drop_indexes()
result = db.compras.create_index([('precios', pymongo.ASCENDING)],
                                   unique=False)
print(result)
# Out:
# precios_1

# %% [markdown]
# Estamos interesados en saber los nombres de los menores que han hecho alguna compra

# %%
query = db.compras.find({"edad":{"$lt":18}})
for doc in query:
    print(doc['nombre'],doc['edad'])
# Out:
# bertoldo_5 14
# bertoldo_14 12
# calixta_19 3
# herminia_23 9
# calixta_27 4
# bertoldo_34 10
# bertoldo_35 15
# calixta_36 3
# melibea_37 1
# bertoldo_41 16
# calixta_43 11
# bertoldo_50 11
# melibea_58 6
# aniceto_60 17
# melibea_88 9
# aniceto_89 13
# melibea_92 16
# aniceto_97 5
# melibea_102 11
# melibea_107 9
# calixta_109 1
# herminia_110 17
# melibea_114 12
# melibea_120 10
# bertoldo_127 8
# melibea_131 10
# herminia_137 11
# melibea_141 5
# calixta_143 12
# herminia_146 6
# herminia_171 16
# herminia_172 7
# calixta_182 16
# aniceto_186 7
# aniceto_191 8
# herminia_213 11
# bertoldo_214 11
# bertoldo_221 8
# aniceto_224 11
# calixta_225 4
# herminia_227 8
# herminia_229 8
# calixta_230 17
# melibea_242 11
# aniceto_249 1
# calixta_274 1
# herminia_276 12
# herminia_278 14
# melibea_285 13
# bertoldo_286 15
# aniceto_290 17
# calixta_297 7
# aniceto_306 8
# herminia_309 15
# calixta_317 14
# aniceto_327 3
# aniceto_334 12
# herminia_335 12
# calixta_357 8
# herminia_385 8
# bertoldo_389 13
# herminia_405 9
# bertoldo_410 17
# aniceto_416 10
# herminia_424 12
# herminia_430 7
# aniceto_431 5
# bertoldo_434 8
# melibea_435 2
# herminia_438 15
# calixta_445 3
# herminia_449 16
# melibea_455 12
# bertoldo_460 2
# bertoldo_476 13
# melibea_484 14
# bertoldo_494 15
# bertoldo_496 14
# melibea_500 7
# calixta_504 15
# bertoldo_510 14
# calixta_511 16
# herminia_517 7
# aniceto_521 2
# melibea_530 14
# herminia_532 1
# herminia_535 16
# bertoldo_542 9
# bertoldo_545 6
# herminia_547 9
# aniceto_569 13
# calixta_573 10
# calixta_583 4
# bertoldo_587 13
# melibea_588 7
# melibea_600 11
# aniceto_601 16
# aniceto_609 14
# calixta_611 5
# aniceto_613 3
# melibea_617 6
# bertoldo_621 5
# calixta_627 7
# calixta_631 3
# aniceto_635 12
# herminia_648 13
# herminia_653 6
# aniceto_659 5
# aniceto_662 15
# calixta_676 9
# calixta_680 16
# bertoldo_682 15
# herminia_683 3
# herminia_690 11
# aniceto_693 16
# bertoldo_694 11
# aniceto_695 13
# melibea_716 13
# herminia_723 5
# calixta_729 3
# aniceto_733 15
# calixta_735 17
# bertoldo_736 4
# herminia_741 4
# aniceto_742 12
# herminia_747 12
# herminia_750 13
# aniceto_755 6
# melibea_757 15
# melibea_768 14
# aniceto_788 6
# herminia_792 11
# herminia_817 7
# calixta_826 7
# aniceto_832 14
# herminia_833 16
# bertoldo_834 17
# melibea_839 14
# melibea_845 11
# herminia_847 14
# herminia_849 8
# aniceto_850 3
# aniceto_861 11
# bertoldo_862 8
# bertoldo_869 8
# calixta_876 13
# calixta_877 9
# calixta_878 17
# herminia_892 4
# aniceto_895 12
# melibea_896 6
# bertoldo_898 14
# herminia_899 3
# aniceto_901 5
# herminia_902 17
# aniceto_903 10
# melibea_910 7
# calixta_911 1
# herminia_918 14
# melibea_921 7
# calixta_924 6
# aniceto_930 3
# aniceto_935 3
# aniceto_947 4
# herminia_948 17
# herminia_956 10
# melibea_957 11
# herminia_963 2
# melibea_965 14
# calixta_973 10
# bertoldo_975 11
# calixta_979 7
# herminia_986 5
# calixta_988 9
# aniceto_990 7
# aniceto_992 14

# %% [markdown]
# Queremos saber los nombres de los que hayan hecho alguna compra entre 180 y 190 euros.
# En caso de que haya varios elementos de este tipo nos basta con mostrar el primero
#
# ```
# {'nombre': 'aniceto_3', 'precios': [185]}
# {'nombre': 'herminia_6', 'precios': [183]}
# {'nombre': 'melibea_7', 'precios': [181]}
# {'nombre': 'aniceto_9', 'precios': [190]}
# ```

# %%
query = db.compras.find({"precios":{"$elemMatch":{"$gte":180,"$lte":190}}}) # ,{"nombre":1,"precios.$":1,"_id":0}
for doc in query:
    print(doc)
# Out:
# {'_id': 2, 'nombre': 'calixta_2', 'edad': 67, 'precios': [183, 74, 178, 63, 180, 162, 171, 33, 82, 75, 140, 142, 51], 'dir': {'calle': 'rosa 2', 'num': '15'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 14, 'nombre': 'bertoldo_14', 'edad': 12, 'precios': [110, 104, 23, 65, 135, 180, 186, 105, 13, 180, 60, 126, 138, 139, 139, 47, 133, 8, 11, 72], 'dir': {'calle': 'rosa 4', 'num': '34'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 21, 'nombre': 'herminia_21', 'edad': 36, 'precios': [6, 2, 86, 180, 189, 186, 171, 141, 33], 'dir': {'calle': 'rosa 1', 'num': '30'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 22, 'nombre': 'melibea_22', 'edad': 35, 'precios': [68, 67, 23, 3, 69, 31, 126, 174, 177, 110, 180, 175, 175, 194, 93, 106, 58, 91], 'dir': {'calle': 'rosa 2', 'num': '40'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 48, 'nombre': 'calixta_48', 'edad': 88, 'precios': [8, 128, 180, 112, 52, 151, 12, 45, 5, 132, 134, 106, 49, 94], 'dir': {'calle': 'rosa 8', 'num': '62'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 54, 'nombre': 'calixta_54', 'edad': 86, 'precios': [11, 2, 49, 64, 72, 183, 101, 154, 200, 108, 160, 177, 113, 128, 115, 169, 180, 124, 91, 90, 58], 'dir': {'calle': 'rosa 4', 'num': '75'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 87, 'nombre': 'herminia_87', 'edad': 86, 'precios': [167, 171, 98, 180, 42, 117, 9, 95, 91, 75, 196, 37, 149, 77, 26, 56, 46, 26, 2], 'dir': {'calle': 'rosa 7', 'num': '106'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 88, 'nombre': 'melibea_88', 'edad': 9, 'precios': [176, 150, 180, 98, 98, 192, 84, 39, 40, 11, 142, 28, 67, 2, 112, 22, 19, 191, 34], 'dir': {'calle': 'rosa 8', 'num': '107'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 93, 'nombre': 'herminia_93', 'edad': 70, 'precios': [177, 170, 200, 5, 61, 180, 63], 'dir': {'calle': 'rosa 3', 'num': '100'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 118, 'nombre': 'melibea_118', 'edad': 98, 'precios': [87, 180], 'dir': {'calle': 'rosa 8', 'num': '120'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 131, 'nombre': 'melibea_131', 'edad': 10, 'precios': [52, 87, 71, 165, 151, 72, 136, 125, 64, 49, 187, 154, 103, 180, 23], 'dir': {'calle': 'rosa 1', 'num': '146'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 133, 'nombre': 'calixta_133', 'edad': 18, 'precios': [180, 116, 125, 163, 146, 178], 'dir': {'calle': 'rosa 3', 'num': '139'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 161, 'nombre': 'aniceto_161', 'edad': 64, 'precios': [176, 153, 195, 93, 16, 96, 44, 121, 37, 14, 180, 164, 93, 111, 18, 187, 8], 'dir': {'calle': 'rosa 1', 'num': '178'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 163, 'nombre': 'calixta_163', 'edad': 67, 'precios': [41, 5, 180, 145, 87, 64, 101, 22, 89, 83, 119, 160, 102, 200, 124, 134, 122], 'dir': {'calle': 'rosa 3', 'num': '180'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 177, 'nombre': 'aniceto_177', 'edad': 99, 'precios': [34, 169, 7, 51, 66, 130, 157, 51, 78, 170, 61, 180, 76, 102, 107, 129, 173], 'dir': {'calle': 'rosa 7', 'num': '194'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 215, 'nombre': 'aniceto_215', 'edad': 26, 'precios': [45, 193, 152, 61, 129, 160, 34, 65, 95, 166, 149, 18, 145, 172, 33, 140, 65, 162, 20, 180], 'dir': {'calle': 'rosa 5', 'num': '235'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 224, 'nombre': 'aniceto_224', 'edad': 11, 'precios': [81, 180, 186, 62], 'dir': {'calle': 'rosa 4', 'num': '228'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 225, 'nombre': 'calixta_225', 'edad': 4, 'precios': [197, 33, 27, 175, 32, 79, 159, 180, 45, 188, 139], 'dir': {'calle': 'rosa 5', 'num': '236'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 230, 'nombre': 'calixta_230', 'edad': 17, 'precios': [75, 49, 115, 180, 46, 32, 165, 179], 'dir': {'calle': 'rosa 0', 'num': '238'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 231, 'nombre': 'herminia_231', 'edad': 97, 'precios': [26, 110, 107, 15, 146, 180, 75, 180], 'dir': {'calle': 'rosa 1', 'num': '239'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 236, 'nombre': 'bertoldo_236', 'edad': 35, 'precios': [159, 116, 48, 186, 32, 67, 170, 91, 43, 22, 1, 4, 53, 180, 78, 24, 28], 'dir': {'calle': 'rosa 6', 'num': '253'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 241, 'nombre': 'calixta_241', 'edad': 62, 'precios': [78, 146, 180, 119, 18, 194, 115, 86, 186, 18, 31, 186, 41, 74, 13], 'dir': {'calle': 'rosa 1', 'num': '256'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 263, 'nombre': 'herminia_263', 'edad': 30, 'precios': [24, 84, 175, 30, 89, 30, 180, 49, 118, 152, 5, 68], 'dir': {'calle': 'rosa 3', 'num': '275'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 269, 'nombre': 'melibea_269', 'edad': 45, 'precios': [128, 136, 12, 36, 115, 49, 29, 24, 178, 69, 96, 48, 35, 9, 63, 2, 180, 88], 'dir': {'calle': 'rosa 9', 'num': '287'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 274, 'nombre': 'calixta_274', 'edad': 1, 'precios': [6, 180, 3, 11, 63, 29, 107, 154], 'dir': {'calle': 'rosa 4', 'num': '282'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 312, 'nombre': 'melibea_312', 'edad': 99, 'precios': [149, 90, 192, 116, 98, 153, 85, 43, 168, 77, 168, 110, 164, 180, 117, 115, 46, 179, 43, 5], 'dir': {'calle': 'rosa 2', 'num': '332'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 318, 'nombre': 'bertoldo_318', 'edad': 19, 'precios': [35, 171, 48, 26, 180, 166, 90, 94, 108, 110, 2, 167, 24], 'dir': {'calle': 'rosa 8', 'num': '331'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 321, 'nombre': 'aniceto_321', 'edad': 78, 'precios': [136, 180, 177, 82, 57, 160, 169, 31, 161, 54, 8, 111, 4, 9, 181, 78, 200, 197, 145, 81, 194], 'dir': {'calle': 'rosa 1', 'num': '342'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 331, 'nombre': 'melibea_331', 'edad': 92, 'precios': [180, 124, 180, 9, 67], 'dir': {'calle': 'rosa 1', 'num': '336'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 347, 'nombre': 'melibea_347', 'edad': 81, 'precios': [185, 97, 148, 182, 119, 45, 158, 180, 146, 143, 175, 24, 151, 95, 64, 32, 114], 'dir': {'calle': 'rosa 7', 'num': '364'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 440, 'nombre': 'melibea_440', 'edad': 67, 'precios': [53, 3, 143, 19, 154, 21, 66, 76, 8, 196, 183, 27, 151, 55, 123, 124, 180, 184, 34, 133, 113], 'dir': {'calle': 'rosa 0', 'num': '461'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 472, 'nombre': 'melibea_472', 'edad': 91, 'precios': [154, 180, 39, 167, 130, 95, 165], 'dir': {'calle': 'rosa 2', 'num': '479'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 502, 'nombre': 'bertoldo_502', 'edad': 72, 'precios': [8, 69, 80, 106, 148, 58, 34, 196, 172, 81, 60, 130, 160, 84, 175, 52, 180, 74], 'dir': {'calle': 'rosa 2', 'num': '520'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 525, 'nombre': 'herminia_525', 'edad': 53, 'precios': [194, 122, 75, 180, 56], 'dir': {'calle': 'rosa 5', 'num': '530'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 572, 'nombre': 'herminia_572', 'edad': 99, 'precios': [71, 93, 13, 184, 103, 32, 8, 180, 87, 142, 63, 103, 190], 'dir': {'calle': 'rosa 2', 'num': '585'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 575, 'nombre': 'aniceto_575', 'edad': 30, 'precios': [129, 142, 36, 80, 193, 200, 24, 29, 102, 96, 12, 31, 180, 158, 165, 118, 76], 'dir': {'calle': 'rosa 5', 'num': '592'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 638, 'nombre': 'aniceto_638', 'edad': 35, 'precios': [184, 180, 179, 122, 178], 'dir': {'calle': 'rosa 8', 'num': '643'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 648, 'nombre': 'herminia_648', 'edad': 13, 'precios': [9, 125, 68, 74, 100, 142, 190, 98, 54, 171, 165, 180, 32, 138, 60, 12], 'dir': {'calle': 'rosa 8', 'num': '664'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 658, 'nombre': 'herminia_658', 'edad': 47, 'precios': [161, 147, 94, 108, 139, 66, 157, 101, 155, 194, 130, 30, 31, 77, 37, 162, 191, 89, 180], 'dir': {'calle': 'rosa 8', 'num': '677'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 678, 'nombre': 'melibea_678', 'edad': 22, 'precios': [79, 70, 41, 106, 53, 180, 175, 78, 155, 119, 35, 143, 188, 178, 13, 26], 'dir': {'calle': 'rosa 8', 'num': '694'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 680, 'nombre': 'calixta_680', 'edad': 16, 'precios': [139, 176, 25, 87, 180, 108, 109, 22, 160, 123, 134, 10, 131, 41, 196, 188, 90], 'dir': {'calle': 'rosa 0', 'num': '697'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 731, 'nombre': 'calixta_731', 'edad': 86, 'precios': [180, 21, 166, 132, 130, 60, 144, 178], 'dir': {'calle': 'rosa 1', 'num': '739'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 817, 'nombre': 'herminia_817', 'edad': 7, 'precios': [183, 155, 6, 177, 180, 169, 177, 102, 68, 21, 131, 127, 31, 98, 165, 22], 'dir': {'calle': 'rosa 7', 'num': '833'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 830, 'nombre': 'calixta_830', 'edad': 51, 'precios': [43, 64, 168, 180, 150, 45, 52, 150, 145, 64, 54, 7, 126, 182, 180, 96, 20, 134, 22, 7, 101], 'dir': {'calle': 'rosa 0', 'num': '851'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 844, 'nombre': 'melibea_844', 'edad': 86, 'precios': [158, 39, 100, 147, 142, 164, 98, 180, 135, 22, 149, 74], 'dir': {'calle': 'rosa 4', 'num': '856'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 864, 'nombre': 'herminia_864', 'edad': 87, 'precios': [73, 165, 180, 73, 31, 94, 176, 144, 32, 190], 'dir': {'calle': 'rosa 4', 'num': '874'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 893, 'nombre': 'bertoldo_893', 'edad': 18, 'precios': [180, 41], 'dir': {'calle': 'rosa 3', 'num': '895'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 931, 'nombre': 'melibea_931', 'edad': 28, 'precios': [181, 69, 48, 69, 104, 44, 68, 81, 59, 136, 14, 198, 123, 180, 106, 42, 166], 'dir': {'calle': 'rosa 1', 'num': '948'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 941, 'nombre': 'bertoldo_941', 'edad': 33, 'precios': [39, 180, 54, 191, 11, 179, 196, 34, 185, 136, 4, 34, 129, 196, 144], 'dir': {'calle': 'rosa 1', 'num': '956'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 955, 'nombre': 'calixta_955', 'edad': 47, 'precios': [30, 196, 159, 148, 56, 66, 195, 60, 191, 17, 132, 140, 85, 167, 152, 180, 107, 7, 177, 32, 86], 'dir': {'calle': 'rosa 5', 'num': '976'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 962, 'nombre': 'calixta_962', 'edad': 98, 'precios': [67, 133, 180, 33], 'dir': {'calle': 'rosa 2', 'num': '966'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 986, 'nombre': 'herminia_986', 'edad': 5, 'precios': [149, 5, 144, 53, 36, 95, 12, 199, 58, 180], 'dir': {'calle': 'rosa 6', 'num': '996'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 618000)}
# {'_id': 27, 'nombre': 'calixta_27', 'edad': 4, 'precios': [21, 104, 175, 195, 181, 50, 139, 190, 49, 64, 110, 15, 92, 94, 16, 10, 96, 64, 123, 188], 'dir': {'calle': 'rosa 7', 'num': '47'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 105, 'nombre': 'herminia_105', 'edad': 75, 'precios': [191, 106, 23, 20, 89, 67, 99, 181, 169], 'dir': {'calle': 'rosa 5', 'num': '114'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 113, 'nombre': 'melibea_113', 'edad': 44, 'precios': [77, 32, 25, 49, 151, 181, 8, 137, 17, 146, 79, 34, 115, 9, 28, 116, 120, 75, 51], 'dir': {'calle': 'rosa 3', 'num': '132'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 162, 'nombre': 'calixta_162', 'edad': 25, 'precios': [181, 66, 155, 68, 196, 192, 73, 155, 97, 91, 89, 160, 71, 16, 55, 28, 156, 142, 47, 109, 133], 'dir': {'calle': 'rosa 2', 'num': '183'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 171, 'nombre': 'herminia_171', 'edad': 16, 'precios': [194, 197, 49, 16, 169, 195, 102, 181, 127, 199, 195, 192, 18, 102, 155], 'dir': {'calle': 'rosa 1', 'num': '186'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 173, 'nombre': 'calixta_173', 'edad': 45, 'precios': [46, 192, 181, 85, 50, 90, 55, 125, 53, 30, 96, 99, 143, 101, 112, 65, 121, 93, 176, 55, 13], 'dir': {'calle': 'rosa 3', 'num': '194'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 175, 'nombre': 'bertoldo_175', 'edad': 34, 'precios': [194, 184, 130, 57, 83, 98, 82, 4, 142, 197, 145, 70, 155, 162, 109, 182, 113, 121, 181, 58, 48], 'dir': {'calle': 'rosa 5', 'num': '196'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 195, 'nombre': 'bertoldo_195', 'edad': 100, 'precios': [118, 86, 67, 160, 192, 192, 5, 162, 181, 11, 59, 159, 193, 151, 27, 111, 188, 102], 'dir': {'calle': 'rosa 5', 'num': '213'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 244, 'nombre': 'melibea_244', 'edad': 52, 'precios': [31, 87, 131, 177, 68, 109, 58, 181, 117, 179, 152, 75, 80, 1, 6], 'dir': {'calle': 'rosa 4', 'num': '259'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 258, 'nombre': 'bertoldo_258', 'edad': 49, 'precios': [40, 31, 54, 182, 194, 124, 165, 118, 111, 74, 122, 63, 111, 56, 98, 181, 84, 23, 34, 112, 35], 'dir': {'calle': 'rosa 8', 'num': '279'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 291, 'nombre': 'calixta_291', 'edad': 25, 'precios': [70, 68, 181, 173, 170, 139, 73, 147, 167, 182, 115], 'dir': {'calle': 'rosa 1', 'num': '302'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 311, 'nombre': 'bertoldo_311', 'edad': 35, 'precios': [106, 112, 44, 181, 140, 71, 104, 166, 23, 49, 169, 152, 111], 'dir': {'calle': 'rosa 1', 'num': '324'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 317, 'nombre': 'calixta_317', 'edad': 14, 'precios': [46, 192, 121, 24, 134, 98, 74, 149, 111, 181, 68], 'dir': {'calle': 'rosa 7', 'num': '328'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 343, 'nombre': 'bertoldo_343', 'edad': 52, 'precios': [181, 83, 88, 146, 105, 52, 170, 125, 105, 118, 104, 47, 53, 134], 'dir': {'calle': 'rosa 3', 'num': '357'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 345, 'nombre': 'calixta_345', 'edad': 80, 'precios': [54, 80, 184, 41, 157, 181, 52, 167], 'dir': {'calle': 'rosa 5', 'num': '353'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 346, 'nombre': 'herminia_346', 'edad': 90, 'precios': [9, 50, 163, 116, 11, 123, 39, 158, 49, 88, 33, 92, 181, 144, 184, 21], 'dir': {'calle': 'rosa 6', 'num': '362'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 480, 'nombre': 'calixta_480', 'edad': 76, 'precios': [155, 80, 139, 166, 144, 184, 181, 59, 103, 150, 159, 55, 89, 124, 131, 182], 'dir': {'calle': 'rosa 0', 'num': '496'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 497, 'nombre': 'aniceto_497', 'edad': 70, 'precios': [29, 5, 9, 115, 74, 2, 181, 85], 'dir': {'calle': 'rosa 7', 'num': '505'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 521, 'nombre': 'aniceto_521', 'edad': 2, 'precios': [62, 69, 19, 75, 96, 28, 181], 'dir': {'calle': 'rosa 1', 'num': '528'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 536, 'nombre': 'melibea_536', 'edad': 73, 'precios': [72, 107, 23, 104, 197, 54, 32, 70, 92, 187, 181], 'dir': {'calle': 'rosa 6', 'num': '547'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 559, 'nombre': 'herminia_559', 'edad': 67, 'precios': [123, 85, 181, 23, 96, 12, 119, 112, 27, 109, 59, 158, 26], 'dir': {'calle': 'rosa 9', 'num': '572'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 573, 'nombre': 'calixta_573', 'edad': 10, 'precios': [166, 120, 115, 181, 148, 31, 138, 58, 149, 71, 197, 144, 84], 'dir': {'calle': 'rosa 3', 'num': '586'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 586, 'nombre': 'herminia_586', 'edad': 70, 'precios': [113, 60, 81, 32, 88, 38, 55, 10, 179, 157, 181, 147], 'dir': {'calle': 'rosa 6', 'num': '598'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 612, 'nombre': 'bertoldo_612', 'edad': 90, 'precios': [92, 179, 16, 159, 55, 51, 59, 193, 160, 79, 65, 1, 200, 45, 16, 24, 181, 158, 170], 'dir': {'calle': 'rosa 2', 'num': '631'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 633, 'nombre': 'bertoldo_633', 'edad': 89, 'precios': [110, 197, 187, 48, 137, 181], 'dir': {'calle': 'rosa 3', 'num': '639'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 695, 'nombre': 'aniceto_695', 'edad': 13, 'precios': [44, 86, 21, 43, 181, 84], 'dir': {'calle': 'rosa 5', 'num': '701'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 699, 'nombre': 'aniceto_699', 'edad': 51, 'precios': [8, 79, 62, 24, 198, 36, 94, 39, 58, 173, 117, 43, 115, 54, 134, 181, 19, 169], 'dir': {'calle': 'rosa 9', 'num': '717'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 754, 'nombre': 'aniceto_754', 'edad': 73, 'precios': [45, 3, 150, 68, 137, 157, 191, 109, 98, 151, 46, 159, 181, 142, 17], 'dir': {'calle': 'rosa 4', 'num': '769'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 760, 'nombre': 'bertoldo_760', 'edad': 65, 'precios': [83, 2, 109, 62, 116, 60, 135, 67, 158, 72, 181, 35, 181, 101, 119], 'dir': {'calle': 'rosa 0', 'num': '775'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 769, 'nombre': 'melibea_769', 'edad': 23, 'precios': [107, 200, 200, 96, 181, 16, 93, 189, 188, 62, 181, 197, 65], 'dir': {'calle': 'rosa 9', 'num': '782'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 781, 'nombre': 'aniceto_781', 'edad': 28, 'precios': [170, 7, 15, 181, 19, 84, 47, 70, 46, 154, 139, 147, 161, 31, 136, 178], 'dir': {'calle': 'rosa 1', 'num': '797'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 816, 'nombre': 'bertoldo_816', 'edad': 80, 'precios': [63, 122, 11, 51, 45, 81, 92, 97, 2, 56, 115, 114, 9, 122, 36, 181, 151, 133, 135, 130, 142], 'dir': {'calle': 'rosa 6', 'num': '837'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 833, 'nombre': 'herminia_833', 'edad': 16, 'precios': [166, 8, 135, 93, 121, 168, 165, 187, 20, 132, 76, 181, 25, 140, 139, 114, 95, 36, 53], 'dir': {'calle': 'rosa 3', 'num': '852'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 845, 'nombre': 'melibea_845', 'edad': 11, 'precios': [135, 18, 58, 3, 181, 117, 69, 20, 70], 'dir': {'calle': 'rosa 5', 'num': '854'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 853, 'nombre': 'aniceto_853', 'edad': 75, 'precios': [181, 198, 199, 78, 98, 51, 57, 35, 96, 2, 144, 33, 22, 145, 82, 185, 22, 100, 115, 124, 61], 'dir': {'calle': 'rosa 3', 'num': '874'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 857, 'nombre': 'calixta_857', 'edad': 28, 'precios': [59, 136, 76, 181, 111, 64, 170], 'dir': {'calle': 'rosa 7', 'num': '864'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 885, 'nombre': 'aniceto_885', 'edad': 33, 'precios': [38, 109, 174, 198, 41, 115, 40, 92, 114, 87, 185, 164, 140, 16, 4, 157, 81, 181, 103, 192, 24], 'dir': {'calle': 'rosa 5', 'num': '906'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 902, 'nombre': 'herminia_902', 'edad': 17, 'precios': [191, 92, 181, 15, 176, 102, 155, 1, 17, 150, 122], 'dir': {'calle': 'rosa 2', 'num': '913'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 903, 'nombre': 'aniceto_903', 'edad': 10, 'precios': [59, 184, 146, 26, 150, 157, 95, 62, 188, 77, 190, 171, 108, 47, 181, 150, 154, 26, 178, 27], 'dir': {'calle': 'rosa 3', 'num': '923'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 951, 'nombre': 'melibea_951', 'edad': 49, 'precios': [56, 131, 136, 138, 117, 87, 153, 142, 25, 23, 172, 42, 181, 52, 125, 168, 62, 26, 3, 199, 107], 'dir': {'calle': 'rosa 1', 'num': '972'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 959, 'nombre': 'bertoldo_959', 'edad': 93, 'precios': [15, 16, 169, 79, 49, 65, 68, 107, 188, 53, 48, 144, 137, 181, 10], 'dir': {'calle': 'rosa 9', 'num': '974'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 996, 'nombre': 'calixta_996', 'edad': 77, 'precios': [197, 139, 181, 108, 127, 123, 147, 101, 139, 172, 144, 135, 14, 114, 98, 35], 'dir': {'calle': 'rosa 6', 'num': '1012'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 618000)}
# {'_id': 30, 'nombre': 'herminia_30', 'edad': 36, 'precios': [64, 93, 2, 152, 182, 124, 194, 44], 'dir': {'calle': 'rosa 0', 'num': '38'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 33, 'nombre': 'herminia_33', 'edad': 66, 'precios': [94, 103, 79, 196, 59, 4, 35, 174, 139, 182, 163, 123, 120, 34], 'dir': {'calle': 'rosa 3', 'num': '47'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 40, 'nombre': 'herminia_40', 'edad': 23, 'precios': [118, 50, 65, 54, 66, 154, 182, 115, 31, 197, 165, 63, 45], 'dir': {'calle': 'rosa 0', 'num': '53'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 55, 'nombre': 'melibea_55', 'edad': 61, 'precios': [194, 61, 84, 168, 97, 155, 182], 'dir': {'calle': 'rosa 5', 'num': '62'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 58, 'nombre': 'melibea_58', 'edad': 6, 'precios': [89, 144, 99, 123, 182], 'dir': {'calle': 'rosa 8', 'num': '63'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 59, 'nombre': 'bertoldo_59', 'edad': 42, 'precios': [96, 87, 96, 127, 71, 99, 30, 185, 142, 187, 106, 47, 110, 174, 160, 176, 81, 182, 114, 167], 'dir': {'calle': 'rosa 9', 'num': '79'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 111, 'nombre': 'bertoldo_111', 'edad': 81, 'precios': [59, 16, 29, 151, 198, 157, 161, 182, 169], 'dir': {'calle': 'rosa 1', 'num': '120'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 117, 'nombre': 'calixta_117', 'edad': 57, 'precios': [35, 182, 122, 158, 72, 75, 133, 192, 12, 169, 131, 119], 'dir': {'calle': 'rosa 7', 'num': '129'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 137, 'nombre': 'herminia_137', 'edad': 11, 'precios': [72, 25, 72, 138, 21, 164, 24, 182, 9, 125, 29, 109, 48, 69, 138, 124, 149, 12], 'dir': {'calle': 'rosa 7', 'num': '155'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 145, 'nombre': 'bertoldo_145', 'edad': 53, 'precios': [1, 32, 153, 108, 182, 97, 173, 13, 83, 128], 'dir': {'calle': 'rosa 5', 'num': '155'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 184, 'nombre': 'herminia_184', 'edad': 26, 'precios': [95, 113, 112, 119, 97, 99, 141, 178, 64, 123, 182, 132, 17, 98, 82, 79], 'dir': {'calle': 'rosa 4', 'num': '200'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 200, 'nombre': 'melibea_200', 'edad': 69, 'precios': [61, 40, 57, 113, 114, 90, 182, 150], 'dir': {'calle': 'rosa 0', 'num': '208'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 227, 'nombre': 'herminia_227', 'edad': 8, 'precios': [152, 58, 137, 9, 74, 133, 81, 113, 41, 104, 151, 139, 182, 49, 94, 136, 22, 100, 143, 121, 72], 'dir': {'calle': 'rosa 7', 'num': '248'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 235, 'nombre': 'bertoldo_235', 'edad': 47, 'precios': [2, 145, 91, 195, 150, 167, 182, 108, 169, 200, 7, 197, 132, 74, 187, 132, 53, 190, 85], 'dir': {'calle': 'rosa 5', 'num': '254'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 313, 'nombre': 'calixta_313', 'edad': 49, 'precios': [41, 126, 124, 182, 2, 23], 'dir': {'calle': 'rosa 3', 'num': '319'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 332, 'nombre': 'aniceto_332', 'edad': 59, 'precios': [65, 182, 14, 179, 148, 33, 130, 156, 62, 1, 106], 'dir': {'calle': 'rosa 2', 'num': '343'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 370, 'nombre': 'bertoldo_370', 'edad': 37, 'precios': [182, 128, 69, 81, 122, 11, 103, 86, 165, 152, 44, 94], 'dir': {'calle': 'rosa 0', 'num': '382'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 413, 'nombre': 'herminia_413', 'edad': 29, 'precios': [52, 9, 156, 158, 182], 'dir': {'calle': 'rosa 3', 'num': '418'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 421, 'nombre': 'aniceto_421', 'edad': 91, 'precios': [111, 18, 11, 171, 168, 170, 109, 141, 122, 101, 115, 182, 107, 121, 167, 111], 'dir': {'calle': 'rosa 1', 'num': '437'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 426, 'nombre': 'bertoldo_426', 'edad': 41, 'precios': [94, 74, 182, 120, 118, 99, 36, 134, 137, 25, 166, 125, 154, 86], 'dir': {'calle': 'rosa 6', 'num': '440'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 435, 'nombre': 'melibea_435', 'edad': 2, 'precios': [177, 182, 23, 200, 171, 29, 138, 156, 138, 128, 83], 'dir': {'calle': 'rosa 5', 'num': '446'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 436, 'nombre': 'herminia_436', 'edad': 79, 'precios': [24, 136, 169, 157, 171, 150, 84, 87, 189, 114, 37, 90, 68, 182, 195, 11, 70, 158, 29], 'dir': {'calle': 'rosa 6', 'num': '455'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 455, 'nombre': 'melibea_455', 'edad': 12, 'precios': [20, 123, 30, 170, 182, 107, 72, 178, 123, 37, 59, 154, 191, 61, 163], 'dir': {'calle': 'rosa 5', 'num': '470'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 532, 'nombre': 'herminia_532', 'edad': 1, 'precios': [150, 69, 121, 16, 84, 48, 126, 14, 182, 85, 74, 106, 186, 15, 84, 19, 158], 'dir': {'calle': 'rosa 2', 'num': '549'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 546, 'nombre': 'herminia_546', 'edad': 30, 'precios': [193, 62, 198, 182, 154, 64], 'dir': {'calle': 'rosa 6', 'num': '552'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 550, 'nombre': 'bertoldo_550', 'edad': 75, 'precios': [160, 37, 191, 23, 93, 182, 177, 38, 84, 124, 163, 195, 6, 26, 149], 'dir': {'calle': 'rosa 0', 'num': '565'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 558, 'nombre': 'herminia_558', 'edad': 28, 'precios': [50, 52, 192, 89, 110, 97, 127, 182], 'dir': {'calle': 'rosa 8', 'num': '566'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 563, 'nombre': 'calixta_563', 'edad': 74, 'precios': [148, 50, 39, 98, 96, 142, 36, 38, 30, 120, 190, 182, 17, 144, 49, 85, 86, 126], 'dir': {'calle': 'rosa 3', 'num': '581'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 594, 'nombre': 'herminia_594', 'edad': 82, 'precios': [136, 182, 64, 109, 25, 130, 44, 146, 124, 35, 34, 157, 186], 'dir': {'calle': 'rosa 4', 'num': '607'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 596, 'nombre': 'herminia_596', 'edad': 33, 'precios': [160, 114, 12, 158, 151, 131, 108, 190, 146, 182, 128, 91, 80, 77, 69, 119, 42], 'dir': {'calle': 'rosa 6', 'num': '613'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 693, 'nombre': 'aniceto_693', 'edad': 16, 'precios': [10, 109, 182, 81, 30, 32, 70, 188, 130, 1, 11, 173, 3, 76, 149, 88, 196], 'dir': {'calle': 'rosa 3', 'num': '710'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 696, 'nombre': 'bertoldo_696', 'edad': 55, 'precios': [132, 94, 182, 44, 194, 9, 123, 48, 158, 199, 141, 99, 80], 'dir': {'calle': 'rosa 6', 'num': '709'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 717, 'nombre': 'herminia_717', 'edad': 55, 'precios': [51, 164, 30, 31, 90, 182, 55, 100, 101, 94, 127, 62], 'dir': {'calle': 'rosa 7', 'num': '729'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 723, 'nombre': 'herminia_723', 'edad': 5, 'precios': [35, 104, 182, 160, 58, 7, 38, 54, 186, 11, 28, 37], 'dir': {'calle': 'rosa 3', 'num': '735'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 748, 'nombre': 'calixta_748', 'edad': 22, 'precios': [182, 86, 168, 126, 6, 88, 165, 27, 16], 'dir': {'calle': 'rosa 8', 'num': '757'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 756, 'nombre': 'melibea_756', 'edad': 22, 'precios': [168, 33, 162, 77, 182, 4, 13, 165, 25, 66, 187, 73, 139, 116], 'dir': {'calle': 'rosa 6', 'num': '770'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 768, 'nombre': 'melibea_768', 'edad': 14, 'precios': [21, 64, 182, 10, 59, 30], 'dir': {'calle': 'rosa 8', 'num': '774'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 772, 'nombre': 'aniceto_772', 'edad': 52, 'precios': [167, 196, 60, 104, 152, 106, 130, 60, 192, 171, 98, 158, 131, 19, 170, 184, 148, 52, 65, 167, 182], 'dir': {'calle': 'rosa 2', 'num': '793'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 793, 'nombre': 'calixta_793', 'edad': 45, 'precios': [28, 79, 29, 182, 90, 65, 118, 12, 17, 122, 48], 'dir': {'calle': 'rosa 3', 'num': '804'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 799, 'nombre': 'aniceto_799', 'edad': 73, 'precios': [182, 115, 163, 114, 157], 'dir': {'calle': 'rosa 9', 'num': '804'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 819, 'nombre': 'melibea_819', 'edad': 30, 'precios': [28, 122, 58, 182, 146, 93, 31, 116, 120], 'dir': {'calle': 'rosa 9', 'num': '828'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 854, 'nombre': 'calixta_854', 'edad': 28, 'precios': [133, 182, 80, 88, 148, 147, 166, 99, 49, 134, 81, 60, 63, 94], 'dir': {'calle': 'rosa 4', 'num': '868'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 917, 'nombre': 'melibea_917', 'edad': 86, 'precios': [58, 91, 144, 167, 182, 57, 186, 142, 136, 194, 154, 15, 96, 18, 28, 35, 60, 9, 153, 196], 'dir': {'calle': 'rosa 7', 'num': '937'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 930, 'nombre': 'aniceto_930', 'edad': 3, 'precios': [174, 15, 98, 36, 148, 111, 182, 92, 38, 12, 83, 126], 'dir': {'calle': 'rosa 0', 'num': '942'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 934, 'nombre': 'calixta_934', 'edad': 62, 'precios': [115, 190, 92, 109, 182, 9], 'dir': {'calle': 'rosa 4', 'num': '940'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 950, 'nombre': 'calixta_950', 'edad': 77, 'precios': [155, 116, 125, 153, 155, 173, 188, 52, 31, 173, 182, 134, 146, 105, 60], 'dir': {'calle': 'rosa 0', 'num': '965'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 953, 'nombre': 'bertoldo_953', 'edad': 40, 'precios': [130, 78, 68, 29, 124, 8, 182, 190, 63, 149], 'dir': {'calle': 'rosa 3', 'num': '963'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 973, 'nombre': 'calixta_973', 'edad': 10, 'precios': [197, 96, 122, 121, 124, 182, 162, 184, 136, 59, 90, 48, 133, 155, 62, 29], 'dir': {'calle': 'rosa 3', 'num': '989'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 618000)}
# {'_id': 992, 'nombre': 'aniceto_992', 'edad': 14, 'precios': [176, 45, 61, 161, 29, 182, 92, 27, 49, 88], 'dir': {'calle': 'rosa 2', 'num': '1002'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 618000)}
# {'_id': 993, 'nombre': 'calixta_993', 'edad': 89, 'precios': [199, 49, 29, 182, 104, 15, 45, 171, 98, 42, 50, 122, 48, 27, 69, 138, 157], 'dir': {'calle': 'rosa 3', 'num': '1010'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 618000)}
# {'_id': 1, 'nombre': 'calixta_1', 'edad': 60, 'precios': [183, 172, 157, 173, 70, 183, 152, 64, 76, 169, 31, 126, 159, 9, 39, 169, 57, 96], 'dir': {'calle': 'rosa 1', 'num': '19'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 3, 'nombre': 'herminia_3', 'edad': 20, 'precios': [183, 116, 141, 110, 133, 20, 64, 89, 35, 37, 38, 25, 187, 161, 48, 164, 122, 157, 60], 'dir': {'calle': 'rosa 3', 'num': '22'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 32, 'nombre': 'herminia_32', 'edad': 38, 'precios': [32, 89, 3, 9, 66, 67, 92, 148, 1, 139, 183, 12, 88, 51, 121, 143, 1, 27, 126, 74, 32], 'dir': {'calle': 'rosa 2', 'num': '53'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 41, 'nombre': 'bertoldo_41', 'edad': 16, 'precios': [25, 110, 183, 161, 129, 101, 77, 183, 168, 90, 42, 6], 'dir': {'calle': 'rosa 1', 'num': '53'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 80, 'nombre': 'bertoldo_80', 'edad': 18, 'precios': [24, 148, 34, 126, 126, 134, 69, 188, 164, 192, 112, 183, 38, 17, 179, 34], 'dir': {'calle': 'rosa 0', 'num': '96'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 89, 'nombre': 'aniceto_89', 'edad': 13, 'precios': [183, 27, 53, 55, 198, 118, 137, 120, 61, 5, 108, 12, 80, 166, 121], 'dir': {'calle': 'rosa 9', 'num': '104'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 106, 'nombre': 'melibea_106', 'edad': 65, 'precios': [121, 24, 116, 30, 11, 98, 77, 183, 50], 'dir': {'calle': 'rosa 6', 'num': '115'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 186, 'nombre': 'aniceto_186', 'edad': 7, 'precios': [90, 3, 183, 10, 145, 169, 9, 188, 114], 'dir': {'calle': 'rosa 6', 'num': '195'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 211, 'nombre': 'calixta_211', 'edad': 48, 'precios': [141, 114, 173, 40, 9, 129, 187, 183, 156, 170], 'dir': {'calle': 'rosa 1', 'num': '221'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 219, 'nombre': 'melibea_219', 'edad': 70, 'precios': [187, 189, 183, 115, 4, 124, 193, 196, 23, 9, 132, 35, 189, 33, 47], 'dir': {'calle': 'rosa 9', 'num': '234'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 229, 'nombre': 'herminia_229', 'edad': 8, 'precios': [100, 114, 37, 34, 192, 42, 101, 123, 23, 145, 183], 'dir': {'calle': 'rosa 9', 'num': '240'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 309, 'nombre': 'herminia_309', 'edad': 15, 'precios': [45, 33, 113, 96, 31, 154, 85, 38, 57, 183, 193, 195, 64, 191, 147, 177, 108], 'dir': {'calle': 'rosa 9', 'num': '326'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 372, 'nombre': 'herminia_372', 'edad': 61, 'precios': [72, 6, 29, 179, 179, 99, 1, 183, 35, 81, 47, 19, 85], 'dir': {'calle': 'rosa 2', 'num': '385'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 384, 'nombre': 'bertoldo_384', 'edad': 20, 'precios': [47, 155, 72, 63, 177, 16, 183], 'dir': {'calle': 'rosa 4', 'num': '391'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 385, 'nombre': 'herminia_385', 'edad': 8, 'precios': [162, 66, 141, 183, 168, 70, 67, 23, 97, 101, 105, 175, 53, 22, 8, 198, 195, 127, 130, 193, 2], 'dir': {'calle': 'rosa 5', 'num': '406'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 452, 'nombre': 'aniceto_452', 'edad': 51, 'precios': [68, 142, 175, 141, 80, 183, 177, 115, 90, 61, 99, 102, 92, 126, 21, 144, 169], 'dir': {'calle': 'rosa 2', 'num': '469'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 490, 'nombre': 'herminia_490', 'edad': 36, 'precios': [31, 103, 6, 185, 173, 93, 148, 166, 95, 113, 183, 111, 161, 146, 186, 151, 54, 84, 138, 51], 'dir': {'calle': 'rosa 0', 'num': '510'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 498, 'nombre': 'bertoldo_498', 'edad': 36, 'precios': [183, 37, 37, 148, 133, 26, 105], 'dir': {'calle': 'rosa 8', 'num': '505'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 520, 'nombre': 'melibea_520', 'edad': 83, 'precios': [183, 106, 195], 'dir': {'calle': 'rosa 0', 'num': '523'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 537, 'nombre': 'calixta_537', 'edad': 88, 'precios': [183, 60, 63, 96, 56, 77, 53, 175, 121, 124, 2, 16, 122, 21], 'dir': {'calle': 'rosa 7', 'num': '551'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 551, 'nombre': 'aniceto_551', 'edad': 42, 'precios': [118, 44, 183, 94, 149, 142, 62, 97, 153, 45, 58, 151, 46, 176], 'dir': {'calle': 'rosa 1', 'num': '565'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 615, 'nombre': 'melibea_615', 'edad': 52, 'precios': [38, 163, 78, 124, 160, 105, 55, 183, 157, 147, 175, 136, 154, 100, 189, 33, 177, 120, 129, 100], 'dir': {'calle': 'rosa 5', 'num': '635'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 617, 'nombre': 'melibea_617', 'edad': 6, 'precios': [71, 20, 31, 144, 172, 127, 183, 24, 176, 89, 195, 165, 161, 60, 129, 128, 71, 87, 152, 197, 126], 'dir': {'calle': 'rosa 7', 'num': '638'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 667, 'nombre': 'herminia_667', 'edad': 80, 'precios': [71, 200, 153, 176, 191, 175, 171, 104, 46, 45, 163, 32, 35, 167, 183, 80, 74, 47], 'dir': {'calle': 'rosa 7', 'num': '685'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 753, 'nombre': 'bertoldo_753', 'edad': 77, 'precios': [186, 115, 200, 66, 37, 124, 43, 183, 59, 197, 46, 10, 38, 179, 171], 'dir': {'calle': 'rosa 3', 'num': '768'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 784, 'nombre': 'calixta_784', 'edad': 19, 'precios': [153, 44, 71, 189, 171, 91, 159, 188, 104, 102, 119, 14, 183, 140, 149, 193, 69, 106, 1, 33], 'dir': {'calle': 'rosa 4', 'num': '804'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 811, 'nombre': 'melibea_811', 'edad': 46, 'precios': [78, 150, 104, 103, 8, 95, 7, 187, 95, 106, 162, 45, 25, 183, 183, 100, 104], 'dir': {'calle': 'rosa 1', 'num': '828'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 841, 'nombre': 'aniceto_841', 'edad': 77, 'precios': [131, 166, 56, 75, 18, 178, 183, 138, 186, 165, 15, 88, 46, 48], 'dir': {'calle': 'rosa 1', 'num': '855'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 909, 'nombre': 'melibea_909', 'edad': 99, 'precios': [118, 29, 183, 111, 2, 139, 118, 18, 174, 186], 'dir': {'calle': 'rosa 9', 'num': '919'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 911, 'nombre': 'calixta_911', 'edad': 1, 'precios': [183, 29, 41, 83, 120, 173, 8, 104, 106, 12, 137, 144, 94, 31, 136, 47, 105, 82, 60], 'dir': {'calle': 'rosa 1', 'num': '930'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 946, 'nombre': 'melibea_946', 'edad': 98, 'precios': [162, 95, 66, 184, 191, 44, 187, 183, 127, 185, 185, 29, 62, 7, 34, 30, 123, 63, 71], 'dir': {'calle': 'rosa 6', 'num': '965'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 991, 'nombre': 'melibea_991', 'edad': 77, 'precios': [173, 21, 73, 145, 48, 54, 183, 169, 131, 175, 58, 57, 83, 150, 124, 78, 57, 5, 122, 193], 'dir': {'calle': 'rosa 1', 'num': '1011'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 618000)}
# {'_id': 6, 'nombre': 'herminia_6', 'edad': 25, 'precios': [197, 161, 196, 194, 90, 63, 184, 44, 16, 21, 67, 133], 'dir': {'calle': 'rosa 6', 'num': '18'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 10, 'nombre': 'melibea_10', 'edad': 68, 'precios': [87, 53, 42, 8, 112, 57, 171, 184, 117, 197, 108, 35, 33, 81, 31], 'dir': {'calle': 'rosa 0', 'num': '25'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 12, 'nombre': 'calixta_12', 'edad': 45, 'precios': [20, 197, 54, 21, 113, 12, 151, 196, 184, 34, 153, 28, 102, 35], 'dir': {'calle': 'rosa 2', 'num': '26'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 76, 'nombre': 'bertoldo_76', 'edad': 76, 'precios': [195, 197, 36, 167, 197, 146, 184, 50, 131, 163, 99], 'dir': {'calle': 'rosa 6', 'num': '87'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 78, 'nombre': 'melibea_78', 'edad': 47, 'precios': [26, 3, 127, 47, 97, 123, 110, 184, 154, 1], 'dir': {'calle': 'rosa 8', 'num': '88'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 134, 'nombre': 'herminia_134', 'edad': 75, 'precios': [143, 184], 'dir': {'calle': 'rosa 4', 'num': '136'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 182, 'nombre': 'calixta_182', 'edad': 16, 'precios': [117, 105, 191, 121, 184, 150, 193, 33, 3, 172, 35, 136, 196, 177, 17, 116, 64], 'dir': {'calle': 'rosa 2', 'num': '199'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 191, 'nombre': 'aniceto_191', 'edad': 8, 'precios': [86, 138, 139, 87, 26, 177, 24, 130, 185, 184, 62, 108], 'dir': {'calle': 'rosa 1', 'num': '203'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 252, 'nombre': 'melibea_252', 'edad': 42, 'precios': [167, 27, 167, 116, 157, 184, 6, 116, 46, 157, 76, 14, 165, 90], 'dir': {'calle': 'rosa 2', 'num': '266'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 259, 'nombre': 'melibea_259', 'edad': 19, 'precios': [62, 165, 59, 60, 104, 184, 81, 160, 100, 2, 123, 81], 'dir': {'calle': 'rosa 9', 'num': '271'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 266, 'nombre': 'calixta_266', 'edad': 71, 'precios': [176, 54, 88, 138, 160, 46, 80, 106, 184, 192, 86, 185], 'dir': {'calle': 'rosa 6', 'num': '278'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 268, 'nombre': 'bertoldo_268', 'edad': 40, 'precios': [18, 18, 163, 83, 111, 75, 101, 121, 27, 184, 193, 195, 178, 41, 30, 184, 81], 'dir': {'calle': 'rosa 8', 'num': '285'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 282, 'nombre': 'herminia_282', 'edad': 98, 'precios': [49, 143, 164, 194, 184, 4, 175, 192], 'dir': {'calle': 'rosa 2', 'num': '290'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 292, 'nombre': 'herminia_292', 'edad': 75, 'precios': [9, 21, 68, 156, 46, 111, 65, 184, 123], 'dir': {'calle': 'rosa 2', 'num': '301'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 305, 'nombre': 'herminia_305', 'edad': 57, 'precios': [155, 127, 142, 179, 199, 175, 184, 198, 44, 179], 'dir': {'calle': 'rosa 5', 'num': '315'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 319, 'nombre': 'melibea_319', 'edad': 53, 'precios': [162, 82, 173, 149, 126, 184, 120, 130, 1, 116, 46, 86, 95, 14, 49, 147, 193, 18], 'dir': {'calle': 'rosa 9', 'num': '337'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 342, 'nombre': 'calixta_342', 'edad': 52, 'precios': [91, 80, 16, 88, 129, 3, 96, 135, 21, 184, 80, 58, 46, 87, 79, 102, 104, 141, 55], 'dir': {'calle': 'rosa 2', 'num': '361'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 352, 'nombre': 'bertoldo_352', 'edad': 75, 'precios': [184, 155, 23], 'dir': {'calle': 'rosa 2', 'num': '355'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 392, 'nombre': 'aniceto_392', 'edad': 37, 'precios': [91, 149, 16, 141, 139, 1, 106, 178, 125, 165, 1, 18, 130, 5, 136, 184, 193, 170, 164, 164], 'dir': {'calle': 'rosa 2', 'num': '412'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 397, 'nombre': 'herminia_397', 'edad': 36, 'precios': [8, 184, 47, 170, 195, 21, 89, 193, 9, 53, 16, 101, 169, 41, 9], 'dir': {'calle': 'rosa 7', 'num': '412'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 428, 'nombre': 'calixta_428', 'edad': 80, 'precios': [149, 137, 139, 184, 103, 22, 190, 7, 9, 102, 96, 169, 19], 'dir': {'calle': 'rosa 8', 'num': '441'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 499, 'nombre': 'calixta_499', 'edad': 36, 'precios': [184, 161, 100, 52, 61, 70, 134, 11, 162, 109], 'dir': {'calle': 'rosa 9', 'num': '509'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 500, 'nombre': 'melibea_500', 'edad': 7, 'precios': [18, 117, 27, 166, 151, 107, 83, 57, 145, 175, 125, 33, 129, 184, 69, 121], 'dir': {'calle': 'rosa 0', 'num': '516'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 516, 'nombre': 'calixta_516', 'edad': 31, 'precios': [4, 49, 184, 52, 23, 69, 148, 106, 59, 115, 78], 'dir': {'calle': 'rosa 6', 'num': '527'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 524, 'nombre': 'bertoldo_524', 'edad': 87, 'precios': [144, 23, 104, 144, 184, 130, 128, 115, 91], 'dir': {'calle': 'rosa 4', 'num': '533'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 540, 'nombre': 'herminia_540', 'edad': 21, 'precios': [184, 82, 57, 185, 88, 11, 123, 160, 157], 'dir': {'calle': 'rosa 0', 'num': '549'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 564, 'nombre': 'aniceto_564', 'edad': 69, 'precios': [33, 130, 58, 35, 72, 130, 96, 114, 51, 59, 184, 23, 17, 186, 97, 144, 186, 197, 48], 'dir': {'calle': 'rosa 4', 'num': '583'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 588, 'nombre': 'melibea_588', 'edad': 7, 'precios': [18, 198, 4, 4, 68, 152, 145, 37, 184, 52, 119, 65, 36, 198, 71, 44, 140, 29], 'dir': {'calle': 'rosa 8', 'num': '606'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 590, 'nombre': 'aniceto_590', 'edad': 50, 'precios': [11, 144, 184, 104, 106, 99, 41, 4, 174, 14, 17, 132, 164, 62, 18, 136], 'dir': {'calle': 'rosa 0', 'num': '606'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 618, 'nombre': 'aniceto_618', 'edad': 46, 'precios': [82, 67, 184, 12, 24, 2, 44, 136, 186, 164, 109, 10, 11, 73], 'dir': {'calle': 'rosa 8', 'num': '632'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 626, 'nombre': 'herminia_626', 'edad': 69, 'precios': [59, 88, 26, 89, 200, 26, 133, 200, 160, 184, 132, 68, 197, 109, 91, 106, 162, 50, 191], 'dir': {'calle': 'rosa 6', 'num': '645'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 664, 'nombre': 'bertoldo_664', 'edad': 25, 'precios': [98, 76, 184, 82, 164, 134, 19, 45, 117, 7, 78, 59], 'dir': {'calle': 'rosa 4', 'num': '676'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 671, 'nombre': 'melibea_671', 'edad': 44, 'precios': [96, 176, 114, 99, 80, 195, 55, 37, 150, 105, 35, 123, 115, 29, 184], 'dir': {'calle': 'rosa 1', 'num': '686'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 672, 'nombre': 'melibea_672', 'edad': 80, 'precios': [143, 127, 190, 179, 158, 59, 192, 178, 136, 100, 23, 136, 184, 3, 17], 'dir': {'calle': 'rosa 2', 'num': '687'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 679, 'nombre': 'bertoldo_679', 'edad': 95, 'precios': [66, 78, 157, 50, 27, 178, 137, 134, 195, 31, 20, 56, 136, 70, 103, 83, 26, 76, 115, 184], 'dir': {'calle': 'rosa 9', 'num': '699'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# ...
# {'_id': 180, 'nombre': 'bertoldo_180', 'edad': 54, 'precios': [13, 58, 36, 79, 62, 81, 139, 96, 25, 196, 48, 188, 142, 146, 111, 8], 'dir': {'calle': 'rosa 0', 'num': '196'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 189, 'nombre': 'melibea_189', 'edad': 22, 'precios': [56, 188], 'dir': {'calle': 'rosa 9', 'num': '191'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 334, 'nombre': 'aniceto_334', 'edad': 12, 'precios': [60, 59, 126, 122, 159, 191, 172, 188, 37, 56, 188, 66], 'dir': {'calle': 'rosa 4', 'num': '346'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 338, 'nombre': 'aniceto_338', 'edad': 88, 'precios': [113, 56, 106, 80, 119, 109, 113, 52, 86, 97, 100, 128, 136, 39, 188, 37, 160, 199], 'dir': {'calle': 'rosa 8', 'num': '356'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 405, 'nombre': 'herminia_405', 'edad': 9, 'precios': [144, 3, 131, 158, 34, 23, 132, 90, 188, 45], 'dir': {'calle': 'rosa 5', 'num': '415'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 506, 'nombre': 'herminia_506', 'edad': 57, 'precios': [150, 82, 188, 108, 27, 161, 38, 98, 57, 169, 54, 156, 3], 'dir': {'calle': 'rosa 6', 'num': '519'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 567, 'nombre': 'bertoldo_567', 'edad': 50, 'precios': [135, 127, 103, 148, 95, 64, 32, 90, 188], 'dir': {'calle': 'rosa 7', 'num': '576'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 598, 'nombre': 'bertoldo_598', 'edad': 31, 'precios': [52, 112, 75, 131, 115, 12, 34, 99, 23, 42, 177, 178, 78, 188, 67], 'dir': {'calle': 'rosa 8', 'num': '613'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 627, 'nombre': 'calixta_627', 'edad': 7, 'precios': [176, 177, 136, 5, 163, 149, 152, 188, 91], 'dir': {'calle': 'rosa 7', 'num': '636'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 614000)}
# {'_id': 716, 'nombre': 'melibea_716', 'edad': 13, 'precios': [147, 117, 139, 53, 50, 59, 22, 57, 188], 'dir': {'calle': 'rosa 6', 'num': '725'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 720, 'nombre': 'bertoldo_720', 'edad': 68, 'precios': [53, 189, 140, 91, 155, 163, 188], 'dir': {'calle': 'rosa 0', 'num': '727'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 742, 'nombre': 'aniceto_742', 'edad': 12, 'precios': [27, 56, 188, 25, 151, 160, 116, 53], 'dir': {'calle': 'rosa 2', 'num': '750'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 751, 'nombre': 'bertoldo_751', 'edad': 23, 'precios': [26, 103, 118, 188, 109, 193, 119, 21, 94], 'dir': {'calle': 'rosa 1', 'num': '760'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 825, 'nombre': 'aniceto_825', 'edad': 47, 'precios': [43, 141, 75, 62, 198, 56, 188, 155], 'dir': {'calle': 'rosa 5', 'num': '833'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 827, 'nombre': 'aniceto_827', 'edad': 70, 'precios': [150, 200, 110, 188, 75], 'dir': {'calle': 'rosa 7', 'num': '832'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 837, 'nombre': 'bertoldo_837', 'edad': 37, 'precios': [57, 171, 13, 81, 135, 30, 120, 94, 188, 77, 6, 99, 39, 160], 'dir': {'calle': 'rosa 7', 'num': '851'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 28, 'nombre': 'herminia_28', 'edad': 90, 'precios': [53, 170, 71, 106, 85, 141, 189, 51], 'dir': {'calle': 'rosa 8', 'num': '36'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 46, 'nombre': 'bertoldo_46', 'edad': 96, 'precios': [93, 76, 126, 144, 179, 179, 43, 73, 189, 82, 128, 147, 172, 85, 89, 127], 'dir': {'calle': 'rosa 6', 'num': '62'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 56, 'nombre': 'herminia_56', 'edad': 91, 'precios': [115, 9, 5, 131, 189, 39], 'dir': {'calle': 'rosa 6', 'num': '62'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 607000)}
# {'_id': 72, 'nombre': 'calixta_72', 'edad': 80, 'precios': [162, 97, 28, 89, 192, 31, 85, 200, 30, 18, 160, 65, 84, 76, 84, 148, 30, 189, 139, 67, 57], 'dir': {'calle': 'rosa 2', 'num': '93'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 81, 'nombre': 'melibea_81', 'edad': 61, 'precios': [58, 189, 85, 59, 123, 88, 67, 160, 67, 2, 22, 74, 114, 126, 80, 169], 'dir': {'calle': 'rosa 1', 'num': '97'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 132, 'nombre': 'calixta_132', 'edad': 70, 'precios': [154, 51, 151, 85, 61, 22, 189, 102, 50, 14, 122, 89], 'dir': {'calle': 'rosa 2', 'num': '144'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 136, 'nombre': 'calixta_136', 'edad': 25, 'precios': [137, 175, 72, 91, 53, 7, 189, 169, 164, 56, 169, 151, 160, 31, 98, 116, 62], 'dir': {'calle': 'rosa 6', 'num': '153'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 142, 'nombre': 'calixta_142', 'edad': 49, 'precios': [189, 68, 106, 169], 'dir': {'calle': 'rosa 2', 'num': '146'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 159, 'nombre': 'melibea_159', 'edad': 44, 'precios': [156, 55, 79, 18, 42, 107, 129, 189, 160, 4, 48, 199, 85, 195, 133, 8], 'dir': {'calle': 'rosa 9', 'num': '175'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 187, 'nombre': 'bertoldo_187', 'edad': 83, 'precios': [119, 158, 29, 68, 67, 34, 109, 189, 75, 111, 81, 124, 130, 89, 58, 166, 112], 'dir': {'calle': 'rosa 7', 'num': '204'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 198, 'nombre': 'aniceto_198', 'edad': 41, 'precios': [166, 82, 30, 138, 168, 189, 45, 96, 196, 92, 143, 49, 82, 154], 'dir': {'calle': 'rosa 8', 'num': '212'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 202, 'nombre': 'bertoldo_202', 'edad': 74, 'precios': [138, 28, 41, 8, 127, 29, 73, 27, 189, 137], 'dir': {'calle': 'rosa 2', 'num': '212'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 217, 'nombre': 'melibea_217', 'edad': 58, 'precios': [72, 15, 189, 179, 28, 93, 155, 160, 194, 69, 92, 122, 116, 10, 17, 142, 102, 87, 65, 126], 'dir': {'calle': 'rosa 7', 'num': '237'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 218, 'nombre': 'melibea_218', 'edad': 84, 'precios': [119, 4, 64, 92, 27, 105, 19, 32, 50, 7, 72, 143, 165, 156, 189, 47, 117, 94], 'dir': {'calle': 'rosa 8', 'num': '236'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 609000)}
# {'_id': 249, 'nombre': 'aniceto_249', 'edad': 1, 'precios': [106, 110, 77, 192, 189, 151, 58, 79, 88, 158], 'dir': {'calle': 'rosa 9', 'num': '259'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 250, 'nombre': 'herminia_250', 'edad': 59, 'precios': [189, 194, 139], 'dir': {'calle': 'rosa 0', 'num': '253'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 265, 'nombre': 'aniceto_265', 'edad': 18, 'precios': [163, 22, 172, 41, 199, 121, 7, 45, 19, 61, 116, 112, 189, 55, 77, 93], 'dir': {'calle': 'rosa 5', 'num': '281'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 351, 'nombre': 'aniceto_351', 'edad': 73, 'precios': [189, 60, 10, 163, 42, 4, 67, 113], 'dir': {'calle': 'rosa 1', 'num': '359'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 362, 'nombre': 'herminia_362', 'edad': 62, 'precios': [100, 58, 35, 189, 84, 124, 19, 136, 155, 109, 26, 13, 129, 119, 171, 18, 75, 82, 158], 'dir': {'calle': 'rosa 2', 'num': '381'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 424, 'nombre': 'herminia_424', 'edad': 12, 'precios': [62, 146, 157, 166, 144, 123, 48, 174, 2, 189], 'dir': {'calle': 'rosa 4', 'num': '434'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 448, 'nombre': 'calixta_448', 'edad': 60, 'precios': [90, 42, 51, 3, 90, 128, 189, 143, 157, 48, 60, 98, 191], 'dir': {'calle': 'rosa 8', 'num': '461'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 453, 'nombre': 'aniceto_453', 'edad': 80, 'precios': [189], 'dir': {'calle': 'rosa 3', 'num': '454'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 474, 'nombre': 'herminia_474', 'edad': 76, 'precios': [35, 21, 106, 92, 149, 191, 189, 13, 80, 101, 19, 38, 21], 'dir': {'calle': 'rosa 4', 'num': '487'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 475, 'nombre': 'herminia_475', 'edad': 18, 'precios': [200, 48, 141, 52, 152, 189, 195, 113], 'dir': {'calle': 'rosa 5', 'num': '483'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 514, 'nombre': 'aniceto_514', 'edad': 21, 'precios': [24, 117, 6, 107, 153, 85, 159, 189, 151, 197, 80, 58, 123, 74], 'dir': {'calle': 'rosa 4', 'num': '528'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 581, 'nombre': 'melibea_581', 'edad': 87, 'precios': [169, 129, 86, 156, 80, 50, 36, 85, 100, 132, 55, 53, 121, 2, 58, 94, 90, 27, 189, 64], 'dir': {'calle': 'rosa 1', 'num': '601'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 735, 'nombre': 'calixta_735', 'edad': 17, 'precios': [198, 134, 131, 189, 1, 73, 1, 13, 22, 90, 85, 195, 161, 92, 124, 131], 'dir': {'calle': 'rosa 5', 'num': '751'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 737, 'nombre': 'bertoldo_737', 'edad': 45, 'precios': [150, 2, 133, 62, 189, 172, 55, 33, 44, 101, 151, 98, 122], 'dir': {'calle': 'rosa 7', 'num': '750'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 783, 'nombre': 'melibea_783', 'edad': 94, 'precios': [131, 75, 141, 189, 111, 136, 97, 150, 122, 60, 36, 132, 122, 13, 100, 150, 35, 87, 127], 'dir': {'calle': 'rosa 3', 'num': '802'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 785, 'nombre': 'melibea_785', 'edad': 28, 'precios': [189, 177, 166, 156, 99, 194, 114, 35, 65, 79, 177, 123, 175, 199, 28], 'dir': {'calle': 'rosa 5', 'num': '800'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 865, 'nombre': 'aniceto_865', 'edad': 23, 'precios': [15, 127, 158, 91, 133, 193, 165, 35, 189, 8, 179], 'dir': {'calle': 'rosa 5', 'num': '876'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 886, 'nombre': 'calixta_886', 'edad': 64, 'precios': [120, 24, 17, 169, 189, 90, 125, 154, 95, 161, 72, 66, 93, 150, 40, 179, 157, 16, 36], 'dir': {'calle': 'rosa 6', 'num': '905'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 888, 'nombre': 'bertoldo_888', 'edad': 72, 'precios': [67, 173, 71, 86, 189], 'dir': {'calle': 'rosa 8', 'num': '893'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 890, 'nombre': 'calixta_890', 'edad': 43, 'precios': [146, 127, 18, 106, 189, 87, 168, 117], 'dir': {'calle': 'rosa 0', 'num': '898'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 928, 'nombre': 'bertoldo_928', 'edad': 52, 'precios': [157, 83, 130, 155, 189, 47, 48, 190, 131, 190, 179, 169, 18, 125, 14, 23, 178], 'dir': {'calle': 'rosa 8', 'num': '945'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 969, 'nombre': 'herminia_969', 'edad': 38, 'precios': [95, 153, 1, 46, 129, 62, 98, 175, 119, 25, 194, 161, 170, 179, 189, 167, 140, 147], 'dir': {'calle': 'rosa 9', 'num': '987'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 618000)}
# {'_id': 101, 'nombre': 'herminia_101', 'edad': 42, 'precios': [21, 150, 197, 95, 47, 52, 190, 196, 108, 67, 145, 135], 'dir': {'calle': 'rosa 1', 'num': '113'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 148, 'nombre': 'herminia_148', 'edad': 100, 'precios': [31, 62, 22, 77, 91, 170, 190, 166, 19, 135, 129, 48], 'dir': {'calle': 'rosa 8', 'num': '160'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 608000)}
# {'_id': 260, 'nombre': 'bertoldo_260', 'edad': 59, 'precios': [161, 113, 31, 162, 101, 136, 137, 95, 46, 21, 118, 54, 95, 144, 43, 93, 190], 'dir': {'calle': 'rosa 0', 'num': '277'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 610000)}
# {'_id': 333, 'nombre': 'herminia_333', 'edad': 39, 'precios': [134, 76, 8, 81, 9, 52, 190, 192, 41, 164, 133, 42, 30, 142, 166, 69, 25, 4], 'dir': {'calle': 'rosa 3', 'num': '351'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 395, 'nombre': 'bertoldo_395', 'edad': 24, 'precios': [160, 190, 158, 40], 'dir': {'calle': 'rosa 5', 'num': '399'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 400, 'nombre': 'herminia_400', 'edad': 25, 'precios': [76, 48, 159, 166, 103, 61, 78, 190, 97, 124, 160, 62, 139, 30, 1, 57], 'dir': {'calle': 'rosa 0', 'num': '416'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 402, 'nombre': 'bertoldo_402', 'edad': 63, 'precios': [69, 42, 16, 99, 137, 199, 24, 190, 103, 172], 'dir': {'calle': 'rosa 2', 'num': '412'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 611000)}
# {'_id': 463, 'nombre': 'melibea_463', 'edad': 78, 'precios': [99, 48, 43, 168, 42, 160, 71, 154, 21, 99, 99, 5, 31, 64, 190, 167], 'dir': {'calle': 'rosa 3', 'num': '479'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 612000)}
# {'_id': 513, 'nombre': 'bertoldo_513', 'edad': 75, 'precios': [10, 151, 130, 190, 96, 199, 152], 'dir': {'calle': 'rosa 3', 'num': '520'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 553, 'nombre': 'melibea_553', 'edad': 97, 'precios': [22, 190, 108, 144, 97, 126, 78, 158, 123, 59, 141, 128], 'dir': {'calle': 'rosa 3', 'num': '565'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 577, 'nombre': 'melibea_577', 'edad': 98, 'precios': [47, 33, 131, 106, 107, 93, 84, 114, 67, 17, 129, 190, 31, 147, 78, 41, 101], 'dir': {'calle': 'rosa 7', 'num': '594'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 613000)}
# {'_id': 741, 'nombre': 'herminia_741', 'edad': 4, 'precios': [167, 108, 115, 93, 75, 190], 'dir': {'calle': 'rosa 1', 'num': '747'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 761, 'nombre': 'calixta_761', 'edad': 36, 'precios': [61, 104, 80, 116, 148, 52, 149, 141, 190, 41], 'dir': {'calle': 'rosa 1', 'num': '771'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 779, 'nombre': 'calixta_779', 'edad': 43, 'precios': [118, 158, 190], 'dir': {'calle': 'rosa 9', 'num': '782'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 615000)}
# {'_id': 855, 'nombre': 'calixta_855', 'edad': 101, 'precios': [156, 85, 160, 103, 56, 54, 190, 96], 'dir': {'calle': 'rosa 5', 'num': '863'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 871, 'nombre': 'melibea_871', 'edad': 39, 'precios': [4, 190, 6, 23, 17], 'dir': {'calle': 'rosa 1', 'num': '876'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 878, 'nombre': 'calixta_878', 'edad': 17, 'precios': [22, 72, 190, 60, 85, 172, 149], 'dir': {'calle': 'rosa 8', 'num': '885'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 616000)}
# {'_id': 901, 'nombre': 'aniceto_901', 'edad': 5, 'precios': [75, 190, 149, 24, 43, 62, 193, 195, 92, 87, 196, 94, 81, 56, 151, 124, 17, 136, 65, 37], 'dir': {'calle': 'rosa 1', 'num': '921'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 918, 'nombre': 'herminia_918', 'edad': 14, 'precios': [93, 11, 175, 62, 190, 162, 176, 93, 166, 56, 154, 3, 45], 'dir': {'calle': 'rosa 8', 'num': '931'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 956, 'nombre': 'herminia_956', 'edad': 10, 'precios': [140, 42, 12, 37, 93, 6, 63, 153, 190, 167, 161], 'dir': {'calle': 'rosa 6', 'num': '967'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}
# {'_id': 964, 'nombre': 'calixta_964', 'edad': 90, 'precios': [125, 74, 83, 54, 197, 190, 171, 72, 96, 138, 147, 133, 49], 'dir': {'calle': 'rosa 4', 'num': '977'}, 'hora': datetime.datetime(2020, 1, 30, 16, 41, 36, 617000)}

# %% [markdown]
# Obtener los documentos de personas que se llamen herminia_XXX y que el número de calle sea menor que 50.

# %%
query = db.compras.find({ "nombre": {"$regex": "^herminia_"} , "$where": "function() { return Number(this.dir.num) > 50; }" },{ "nombre": 1 , "dir.num": 1 , "_id": 0 });
for doc in query:
    print(doc)
# Out:
# {'nombre': 'herminia_32', 'dir': {'num': '53'}}
# {'nombre': 'herminia_40', 'dir': {'num': '53'}}
# {'nombre': 'herminia_56', 'dir': {'num': '62'}}
# {'nombre': 'herminia_65', 'dir': {'num': '69'}}
# {'nombre': 'herminia_66', 'dir': {'num': '76'}}
# {'nombre': 'herminia_75', 'dir': {'num': '91'}}
# {'nombre': 'herminia_87', 'dir': {'num': '106'}}
# {'nombre': 'herminia_93', 'dir': {'num': '100'}}
# {'nombre': 'herminia_99', 'dir': {'num': '104'}}
# {'nombre': 'herminia_101', 'dir': {'num': '113'}}
# {'nombre': 'herminia_103', 'dir': {'num': '113'}}
# {'nombre': 'herminia_105', 'dir': {'num': '114'}}
# {'nombre': 'herminia_110', 'dir': {'num': '115'}}
# {'nombre': 'herminia_116', 'dir': {'num': '129'}}
# {'nombre': 'herminia_119', 'dir': {'num': '127'}}
# {'nombre': 'herminia_124', 'dir': {'num': '132'}}
# {'nombre': 'herminia_134', 'dir': {'num': '136'}}
# {'nombre': 'herminia_137', 'dir': {'num': '155'}}
# {'nombre': 'herminia_138', 'dir': {'num': '153'}}
# {'nombre': 'herminia_140', 'dir': {'num': '141'}}
# {'nombre': 'herminia_144', 'dir': {'num': '163'}}
# {'nombre': 'herminia_146', 'dir': {'num': '160'}}
# {'nombre': 'herminia_148', 'dir': {'num': '160'}}
# {'nombre': 'herminia_154', 'dir': {'num': '159'}}
# {'nombre': 'herminia_171', 'dir': {'num': '186'}}
# {'nombre': 'herminia_172', 'dir': {'num': '175'}}
# {'nombre': 'herminia_181', 'dir': {'num': '202'}}
# {'nombre': 'herminia_184', 'dir': {'num': '200'}}
# {'nombre': 'herminia_188', 'dir': {'num': '189'}}
# {'nombre': 'herminia_197', 'dir': {'num': '214'}}
# {'nombre': 'herminia_203', 'dir': {'num': '212'}}
# {'nombre': 'herminia_205', 'dir': {'num': '212'}}
# {'nombre': 'herminia_213', 'dir': {'num': '230'}}
# {'nombre': 'herminia_227', 'dir': {'num': '248'}}
# {'nombre': 'herminia_229', 'dir': {'num': '240'}}
# {'nombre': 'herminia_231', 'dir': {'num': '239'}}
# {'nombre': 'herminia_237', 'dir': {'num': '256'}}
# {'nombre': 'herminia_240', 'dir': {'num': '250'}}
# {'nombre': 'herminia_250', 'dir': {'num': '253'}}
# {'nombre': 'herminia_251', 'dir': {'num': '256'}}
# {'nombre': 'herminia_253', 'dir': {'num': '267'}}
# {'nombre': 'herminia_263', 'dir': {'num': '275'}}
# {'nombre': 'herminia_271', 'dir': {'num': '292'}}
# {'nombre': 'herminia_275', 'dir': {'num': '278'}}
# {'nombre': 'herminia_276', 'dir': {'num': '287'}}
# {'nombre': 'herminia_278', 'dir': {'num': '279'}}
# {'nombre': 'herminia_279', 'dir': {'num': '290'}}
# {'nombre': 'herminia_282', 'dir': {'num': '290'}}
# {'nombre': 'herminia_292', 'dir': {'num': '301'}}
# {'nombre': 'herminia_293', 'dir': {'num': '299'}}
# {'nombre': 'herminia_299', 'dir': {'num': '311'}}
# {'nombre': 'herminia_301', 'dir': {'num': '308'}}
# {'nombre': 'herminia_305', 'dir': {'num': '315'}}
# {'nombre': 'herminia_308', 'dir': {'num': '313'}}
# {'nombre': 'herminia_309', 'dir': {'num': '326'}}
# {'nombre': 'herminia_320', 'dir': {'num': '328'}}
# {'nombre': 'herminia_333', 'dir': {'num': '351'}}
# {'nombre': 'herminia_335', 'dir': {'num': '343'}}
# {'nombre': 'herminia_336', 'dir': {'num': '347'}}
# {'nombre': 'herminia_339', 'dir': {'num': '339'}}
# {'nombre': 'herminia_346', 'dir': {'num': '362'}}
# {'nombre': 'herminia_350', 'dir': {'num': '353'}}
# {'nombre': 'herminia_360', 'dir': {'num': '379'}}
# {'nombre': 'herminia_362', 'dir': {'num': '381'}}
# {'nombre': 'herminia_367', 'dir': {'num': '373'}}
# {'nombre': 'herminia_372', 'dir': {'num': '385'}}
# {'nombre': 'herminia_375', 'dir': {'num': '387'}}
# {'nombre': 'herminia_376', 'dir': {'num': '395'}}
# {'nombre': 'herminia_377', 'dir': {'num': '388'}}
# {'nombre': 'herminia_381', 'dir': {'num': '383'}}
# {'nombre': 'herminia_385', 'dir': {'num': '406'}}
# {'nombre': 'herminia_387', 'dir': {'num': '399'}}
# {'nombre': 'herminia_397', 'dir': {'num': '412'}}
# {'nombre': 'herminia_400', 'dir': {'num': '416'}}
# {'nombre': 'herminia_405', 'dir': {'num': '415'}}
# {'nombre': 'herminia_409', 'dir': {'num': '414'}}
# {'nombre': 'herminia_411', 'dir': {'num': '421'}}
# {'nombre': 'herminia_413', 'dir': {'num': '418'}}
# {'nombre': 'herminia_418', 'dir': {'num': '422'}}
# {'nombre': 'herminia_422', 'dir': {'num': '423'}}
# {'nombre': 'herminia_423', 'dir': {'num': '430'}}
# {'nombre': 'herminia_424', 'dir': {'num': '434'}}
# {'nombre': 'herminia_430', 'dir': {'num': '431'}}
# {'nombre': 'herminia_432', 'dir': {'num': '434'}}
# {'nombre': 'herminia_436', 'dir': {'num': '455'}}
# {'nombre': 'herminia_437', 'dir': {'num': '449'}}
# {'nombre': 'herminia_438', 'dir': {'num': '453'}}
# {'nombre': 'herminia_443', 'dir': {'num': '450'}}
# {'nombre': 'herminia_449', 'dir': {'num': '451'}}
# {'nombre': 'herminia_451', 'dir': {'num': '453'}}
# {'nombre': 'herminia_458', 'dir': {'num': '463'}}
# {'nombre': 'herminia_459', 'dir': {'num': '478'}}
# {'nombre': 'herminia_466', 'dir': {'num': '479'}}
# {'nombre': 'herminia_468', 'dir': {'num': '469'}}
# {'nombre': 'herminia_471', 'dir': {'num': '473'}}
# {'nombre': 'herminia_474', 'dir': {'num': '487'}}
# {'nombre': 'herminia_475', 'dir': {'num': '483'}}
# {'nombre': 'herminia_478', 'dir': {'num': '488'}}
# {'nombre': 'herminia_479', 'dir': {'num': '480'}}
# {'nombre': 'herminia_490', 'dir': {'num': '510'}}
# {'nombre': 'herminia_491', 'dir': {'num': '494'}}
# {'nombre': 'herminia_492', 'dir': {'num': '503'}}
# {'nombre': 'herminia_506', 'dir': {'num': '519'}}
# {'nombre': 'herminia_507', 'dir': {'num': '518'}}
# {'nombre': 'herminia_517', 'dir': {'num': '529'}}
# {'nombre': 'herminia_518', 'dir': {'num': '523'}}
# {'nombre': 'herminia_519', 'dir': {'num': '529'}}
# {'nombre': 'herminia_525', 'dir': {'num': '530'}}
# {'nombre': 'herminia_532', 'dir': {'num': '549'}}
# {'nombre': 'herminia_535', 'dir': {'num': '553'}}
# {'nombre': 'herminia_540', 'dir': {'num': '549'}}
# {'nombre': 'herminia_544', 'dir': {'num': '547'}}
# {'nombre': 'herminia_546', 'dir': {'num': '552'}}
# {'nombre': 'herminia_547', 'dir': {'num': '552'}}
# {'nombre': 'herminia_558', 'dir': {'num': '566'}}
# {'nombre': 'herminia_559', 'dir': {'num': '572'}}
# {'nombre': 'herminia_570', 'dir': {'num': '575'}}
# {'nombre': 'herminia_571', 'dir': {'num': '581'}}
# {'nombre': 'herminia_572', 'dir': {'num': '585'}}
# {'nombre': 'herminia_578', 'dir': {'num': '591'}}
# {'nombre': 'herminia_582', 'dir': {'num': '583'}}
# {'nombre': 'herminia_584', 'dir': {'num': '597'}}
# {'nombre': 'herminia_586', 'dir': {'num': '598'}}
# {'nombre': 'herminia_594', 'dir': {'num': '607'}}
# {'nombre': 'herminia_595', 'dir': {'num': '606'}}
# {'nombre': 'herminia_596', 'dir': {'num': '613'}}
# {'nombre': 'herminia_605', 'dir': {'num': '615'}}
# {'nombre': 'herminia_610', 'dir': {'num': '613'}}
# {'nombre': 'herminia_619', 'dir': {'num': '624'}}
# {'nombre': 'herminia_625', 'dir': {'num': '638'}}
# {'nombre': 'herminia_626', 'dir': {'num': '645'}}
# {'nombre': 'herminia_628', 'dir': {'num': '644'}}
# {'nombre': 'herminia_629', 'dir': {'num': '630'}}
# {'nombre': 'herminia_632', 'dir': {'num': '642'}}
# {'nombre': 'herminia_634', 'dir': {'num': '641'}}
# {'nombre': 'herminia_648', 'dir': {'num': '664'}}
# {'nombre': 'herminia_649', 'dir': {'num': '660'}}
# {'nombre': 'herminia_650', 'dir': {'num': '666'}}
# {'nombre': 'herminia_653', 'dir': {'num': '659'}}
# {'nombre': 'herminia_655', 'dir': {'num': '665'}}
# {'nombre': 'herminia_657', 'dir': {'num': '664'}}
# {'nombre': 'herminia_658', 'dir': {'num': '677'}}
# {'nombre': 'herminia_665', 'dir': {'num': '684'}}
# {'nombre': 'herminia_667', 'dir': {'num': '685'}}
# {'nombre': 'herminia_669', 'dir': {'num': '675'}}
# {'nombre': 'herminia_683', 'dir': {'num': '688'}}
# {'nombre': 'herminia_685', 'dir': {'num': '685'}}
# {'nombre': 'herminia_689', 'dir': {'num': '710'}}
# {'nombre': 'herminia_690', 'dir': {'num': '709'}}
# {'nombre': 'herminia_704', 'dir': {'num': '710'}}
# {'nombre': 'herminia_705', 'dir': {'num': '710'}}
# {'nombre': 'herminia_706', 'dir': {'num': '725'}}
# {'nombre': 'herminia_707', 'dir': {'num': '711'}}
# {'nombre': 'herminia_712', 'dir': {'num': '713'}}
# {'nombre': 'herminia_713', 'dir': {'num': '725'}}
# {'nombre': 'herminia_715', 'dir': {'num': '715'}}
# {'nombre': 'herminia_717', 'dir': {'num': '729'}}
# {'nombre': 'herminia_723', 'dir': {'num': '735'}}
# {'nombre': 'herminia_724', 'dir': {'num': '731'}}
# {'nombre': 'herminia_732', 'dir': {'num': '746'}}
# {'nombre': 'herminia_734', 'dir': {'num': '735'}}
# {'nombre': 'herminia_740', 'dir': {'num': '757'}}
# {'nombre': 'herminia_741', 'dir': {'num': '747'}}
# {'nombre': 'herminia_744', 'dir': {'num': '750'}}
# {'nombre': 'herminia_747', 'dir': {'num': '755'}}
# {'nombre': 'herminia_750', 'dir': {'num': '763'}}
# {'nombre': 'herminia_762', 'dir': {'num': '778'}}
# {'nombre': 'herminia_767', 'dir': {'num': '783'}}
# {'nombre': 'herminia_773', 'dir': {'num': '779'}}
# {'nombre': 'herminia_789', 'dir': {'num': '793'}}
# {'nombre': 'herminia_792', 'dir': {'num': '810'}}
# {'nombre': 'herminia_801', 'dir': {'num': '805'}}
# {'nombre': 'herminia_817', 'dir': {'num': '833'}}
# {'nombre': 'herminia_820', 'dir': {'num': '821'}}
# {'nombre': 'herminia_823', 'dir': {'num': '834'}}
# {'nombre': 'herminia_833', 'dir': {'num': '852'}}
# {'nombre': 'herminia_835', 'dir': {'num': '846'}}
# {'nombre': 'herminia_836', 'dir': {'num': '847'}}
# {'nombre': 'herminia_838', 'dir': {'num': '844'}}
# {'nombre': 'herminia_842', 'dir': {'num': '843'}}
# {'nombre': 'herminia_847', 'dir': {'num': '855'}}
# {'nombre': 'herminia_848', 'dir': {'num': '866'}}
# {'nombre': 'herminia_849', 'dir': {'num': '854'}}
# {'nombre': 'herminia_856', 'dir': {'num': '860'}}
# {'nombre': 'herminia_858', 'dir': {'num': '858'}}
# {'nombre': 'herminia_859', 'dir': {'num': '859'}}
# {'nombre': 'herminia_860', 'dir': {'num': '864'}}
# {'nombre': 'herminia_864', 'dir': {'num': '874'}}
# {'nombre': 'herminia_874', 'dir': {'num': '879'}}
# {'nombre': 'herminia_889', 'dir': {'num': '891'}}
# {'nombre': 'herminia_892', 'dir': {'num': '906'}}
# {'nombre': 'herminia_894', 'dir': {'num': '904'}}
# {'nombre': 'herminia_899', 'dir': {'num': '904'}}
# {'nombre': 'herminia_902', 'dir': {'num': '913'}}
# {'nombre': 'herminia_904', 'dir': {'num': '916'}}
# {'nombre': 'herminia_907', 'dir': {'num': '907'}}
# {'nombre': 'herminia_912', 'dir': {'num': '914'}}
# {'nombre': 'herminia_918', 'dir': {'num': '931'}}
# {'nombre': 'herminia_922', 'dir': {'num': '940'}}
# {'nombre': 'herminia_925', 'dir': {'num': '926'}}
# {'nombre': 'herminia_927', 'dir': {'num': '935'}}
# {'nombre': 'herminia_929', 'dir': {'num': '947'}}
# {'nombre': 'herminia_933', 'dir': {'num': '937'}}
# {'nombre': 'herminia_948', 'dir': {'num': '956'}}
# {'nombre': 'herminia_952', 'dir': {'num': '954'}}
# {'nombre': 'herminia_956', 'dir': {'num': '967'}}
# {'nombre': 'herminia_958', 'dir': {'num': '963'}}
# {'nombre': 'herminia_961', 'dir': {'num': '965'}}
# {'nombre': 'herminia_963', 'dir': {'num': '970'}}
# {'nombre': 'herminia_966', 'dir': {'num': '969'}}
# {'nombre': 'herminia_969', 'dir': {'num': '987'}}
# {'nombre': 'herminia_971', 'dir': {'num': '992'}}
# {'nombre': 'herminia_978', 'dir': {'num': '987'}}
# {'nombre': 'herminia_980', 'dir': {'num': '986'}}
# {'nombre': 'herminia_981', 'dir': {'num': '998'}}
# {'nombre': 'herminia_985', 'dir': {'num': '995'}}
# {'nombre': 'herminia_986', 'dir': {'num': '996'}}
# {'nombre': 'herminia_989', 'dir': {'num': '1007'}}
# {'nombre': 'herminia_995', 'dir': {'num': '995'}}
# {'nombre': 'herminia_998', 'dir': {'num': '1016'}}
