# %% [markdown]
# ![title](https://ucm.es/themes/ucm16/media/img/logo.png)
#
# # Bases de datos NoSQL
#
# ### Práctica Redis. Servicios de publicación/subscripción
#
# #### Parte 1. Publicación
#
# Vamos a publicar las noticias de una página web- Necesitaremos las bibliotecas:
#
# * requests: para bajar páginas completas a partir de la url
# * bs4: beatifulsoap, para procesar los htmls buscando las cabeceras
#
# Si no tenemos instala alguna de ellas, desde una consola de Anaconda (Anaconda prompt)
#
#     pip install bs4
#     pip install requests
#
# Lo primero,  el nombre:

# %% [markdown]
# Nombre:

# %% [markdown]
# Ahora conectamos a Redis. Es importante que cambieis los datos por los de vuestra cuenta, para no saturar el servidor

# %%
# Solución

# Conexión a Redislabs de Rafa.
# import redis
# redisconexion = "redis-13665.c55.eu-central-1-1.ec2.cloud.redislabs.com"
# redispuerto = 13665
# passwd = "csVe77ZtQL7sKQocZZHUlnjmSf0WpGxE"
# r = redis.Redis(host=redisconexion, password=passwd, port=redispuerto, charset="utf-8", decode_responses=True, db=0)
# r.ping() # debe mostrar True

# Mi conexion a Redislabs.
import redis
r = redis.Redis(host="redis-12653.c99.us-east-1-4.ec2.cloud.redislabs.com", password="ukejrL903jt0xlfe6lVwAahKPpQ3XNlW", port=12653, charset="utf-8", decode_responses=True, db=0);
print("Se pudo conectar con Redislabs ???: ",r.ping());

# Conexión a Redis en localhost.
# import redis
# r = redis.Redis(host="localhost", charset="utf-8", decode_responses=True, db=0);
# print("Se pudo conectar con Redis ???:",r.ping());
# Out:
# Se pudo conectar con Redislabs ???:  True

# %% [markdown]
# ### Pregunta 1: 4 puntos
#
# La siguiente función es la que tenéis que modificar. Le van a ir llegando titulares, que son strings. Ahora mismo solo los muestra por pantalla, pero hay que reemplazar el print por vuestro código.
#
# En particular:
#
# * Si el titular contiene al menos un símbolo monetario ('₹','$','£','€') seguidos por un dígito dígito 0,1...9, debe enviarse por el canal `news-money`
#
# * Si no se da el caso anterior, pero el titular contiene alguna de las palabras del array "especiales" enviará la noticia por el canal `news-selected`.  Nota: basta con que tenga la secuencia de caracteres consecutivos, no hace falta mirar si tiene espacio antes o después, etc. Por ejemplo la palabra 'abra' estaría según estadefinición dentro de la frase "y dijo ¡abracadabra!"
#
# * En otro caso enviará  por `news-other`
#
# Completar las funciones  `contiene_monetario`, `contiene_selected`y utilizarlas en trata_titular para publicar cada titular en el canal adecuado

# %%
# Comprueba si 'titular' tiene un símbolo monetario seguido por un dígito 
# devuelve True en el primer caso o False en otro caso.

# Solucion:
def contiene_monetario(titular, simbolos = ['₹','$','£','€']):
    
    for simbolo in simbolos:
    
        if titular.find(simbolo) != -1:
            
            return True;
    
    return False;
    
# Comprueba si 'titular' tiene una palabra especial devuelve True en el
# primer caso o False en otro caso.

# Solucion:
def contiene_selected(titular, especiales = ["US", "India", "Spain", "UK", "Trump"]):

    for especial in especiales:
    
        if titular.find(especial) != -1:
            
            return True;
    
    return False;

# Publica el titular o bien en 'news-money', o en 'news-selected' o en 'news-other' 
# utilizar contiene_monetario y contiene_selected.

# Solucion:
def trata_titular(titular):
    
    if contiene_monetario(titular):
        
        canal = "news-money"
        
        r.publish(canal,titular)
        
    elif contiene_selected(titular):
        
        canal = "news-selected"
        
        r.publish(canal,titular)
        
    else:
        
        canal = "news-other"
    
        r.publish(canal,titular)
    
    print("Titular:",titular) 
    print("Publicado en el canal:",canal,"\n")

# %% [markdown]
# Se puede usar este código para probar `contiene_monetario` y `contiene_selected`. Debe mostrar
#
#
#     False
#     True
#     True
#     True
#     False

# %%
# debe devolver false
print(contiene_monetario("Railways announces 2.3 lakh vacancies; 10% EWS quota applicable"))
# debe devolver true
print(contiene_monetario("Zynga Co-founder raising $700 mn for investment fund"))
# debe devolver true
print(contiene_selected("Self-driving robots to deliver food on US university campus"))
# debe devolver true
print(contiene_selected("Wonderful work of Indian cinema: Sadhguru on 'Manikarnika'"))
# debe devolver false
print(contiene_selected("Your sense of sanctity does not lie in your body: Swara Bhasker"))
# Out:
# False
# True
# True
# True
# False

# %% [markdown]
# ### Publisher
#
# La siguiente casilla de código es la que debemos ejecutar antes de hacer cualquier prueba tras una subscripción, para alimentar al subscriptor de mensajes. No hay que tocar ni cambiar nada.
#
# El código baja titulares  de forma continua hasta alcanzar las 100 noticias.  Para cada titular llama a la función anterior `trata_titular`. Lo he sacado de este sitio:
#
# https://www.pythoncircle.com/post/678/python-script-14-scraping-news-headlines-using-python-beautifulsoup/

# %%
import requests
from bs4 import BeautifulSoup
import json

MAX_NEWS = 100


def headlines(response_text):
    total = 0
    soup = BeautifulSoup(response_text, 'lxml')
    headlines = soup.find_all(attrs={"itemprop": "headline"})
    for headline in headlines:
        trata_titular(headline.text)
        total+=1
    return total


def get_headers():
    return {
        "accept": "*/*",
        "accept-encoding": "gzip, deflate, br",
        "accept-language": "en-IN,en-US;q=0.9,en;q=0.8",
        "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
        "cookie": "_ga=GA1.2.474379061.1548476083; _gid=GA1.2.251903072.1548476083; __gads=ID=17fd29a6d34048fc:T=1548476085:S=ALNI_MaRiLYBFlMfKNMAtiW0J3b_o0XGxw",
        "origin": "https://inshorts.com",
        "referer": "https://inshorts.com/en/read/",
        "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36",
        "x-requested-with": "XMLHttpRequest"
    }


url = 'https://inshorts.com/en/read'
response = requests.get(url)
total = headlines(response.text)

# get more news
url = 'https://inshorts.com/en/ajax/more_news'
news_offset = "apwuhnrm-1"

while total<MAX_NEWS:
    response = requests.post(url, data={"category": "", "news_offset": news_offset}, headers=get_headers())
    if response.status_code != 200:
        print(response.status_code)
        break

    response_json = json.loads(response.text)
    total += headlines(response_json["html"])
    news_offset = response_json["min_news_id"]
# Out:
# Titular: Uttar Pradesh reports 67 new coronavirus cases, state total rises to 727
# Publicado en el canal: news-other
#
# Titular: Delhi reports 17 new coronavirus cases, total rises to 1,578; death toll at 32
# Publicado en el canal: news-other
#
# Titular: Rajasthan reports 71 new coronavirus cases, state total reaches 1,076
# Publicado en el canal: news-other
#
# Titular: Total number of coronavirus cases in Telangana reaches 650; death toll at 18
# Publicado en el canal: news-other
#
# Titular: Sussanne Khan's sister's in-house staff tests COVID-19 +ve; family to self-isolate
# Publicado en el canal: news-other
#
# Titular: Flight carrying 50,000 PPE kits from China lands in Guwahati, Himanta shares pic
# Publicado en el canal: news-other
#
# Titular: Hundreds of migrant workers gather in Surat for 2nd consecutive day
# Publicado en el canal: news-other
#
# Titular: Arunachal Pradesh's only COVID-19 patient's third test comes negative
# Publicado en el canal: news-other
#
# Titular: Patient makes vulgar remarks on female doctor in Delhi hospital; doctors manhandled
# Publicado en el canal: news-other
#
# Titular: We regret Trump's decision to halt US' funding: WHO
# Publicado en el canal: news-selected
#
# Titular: Migrant worker fainted outside my house, spotted through CCTV: Mohammad Shami
# Publicado en el canal: news-other
#
# Titular: Report says PM didn't consult 21-member taskforce over lockdown, ICMR denies
# Publicado en el canal: news-other
#
# Titular: Videos of foreigners partying in Bali amid coronavirus pandemic surface, criticised
# Publicado en el canal: news-other
#
# Titular: COVID-19 hasn't entered 400 districts, next 2-3 weeks crucial: Harsh Vardhan
# Publicado en el canal: news-other
#
# Titular: Pichai, Nadella, 4 other Indian-Americans on Trump's team to revive US economy
# Publicado en el canal: news-selected
#
# Titular: Man coughs while playing ludo in UP, friend shoots at him after argument
# Publicado en el canal: news-other
#
# Titular: Wanted both our kids to have Muslim first name & Hindu surname: Aayush
# Publicado en el canal: news-other
#
# Titular: I'm financially broke, living a life never imagined: Actress Payal
# Publicado en el canal: news-other
#
# Titular: Russia records biggest one-day jump in COVID-19 cases at 3,388
# Publicado en el canal: news-other
#
# Titular: UAE releases 400 Pakistani prisoners amid coronavirus pandemic
# Publicado en el canal: news-other
#
# Titular: COVID-19 pandemic could trigger social unrest in some countries: IMF
# Publicado en el canal: news-other
#
# Titular: Chhattisgarh to adopt pool sample testing for COVID-19: Health Minister
# Publicado en el canal: news-other
#
# Titular: People may need to practice social-distancing till 2022 without vaccine: Harvard
# Publicado en el canal: news-other
#
# Titular: WeWork plans to fire more people by end of May: Reports
# Publicado en el canal: news-other
#
# Titular: Over 10.2 lakh refunds worth ₹4,250 crore issued in a week: CBDT
# Publicado en el canal: news-money
#
# Titular: Govt to confer 4 Padma Vibhushan, 14 Padma Bhushan awards this year
# Publicado en el canal: news-other
#
# Titular: We forgive Sarfaraz but won't take his remarks lightly: SA captain
# Publicado en el canal: news-other
#
# Titular: Hardik Pandya, KL Rahul have really suffered: Azharuddin
# Publicado en el canal: news-other
#
# Titular: Haal behaal hai, jokes Yuvraj as Gambhir asks about married life
# Publicado en el canal: news-other
#
# Titular: Hardik, Rahul were gracious when I apologised to them: Karan Johar
# Publicado en el canal: news-other
#
# Titular: Sarfaraz personally apologises to SA player he called 'Abey Kaale'
# Publicado en el canal: news-other
#
# Titular: Gambhir, Chhetri among 9 sports personalities to get Padma Awards
# Publicado en el canal: news-other
#
# Titular: Zuckerberg may integrate WhatsApp, Instagram, Messenger: NYT
# Publicado en el canal: news-other
#
# Titular: Angola decriminalises homosexuality
# Publicado en el canal: news-other
#
# Titular: Nirav Modi's ₹100-crore sea-facing Alibaug bungalow being demolished
# Publicado en el canal: news-money
#
# Titular: Zee firms lose ₹14,000 crore market value in a day after media report
# Publicado en el canal: news-money
#
# Titular: Language politicians use spoils younger generation: Gulzar
# Publicado en el canal: news-other
#
# Titular: Who is Bhupen Hazarika, late singer who was awarded Bharat Ratna?
# Publicado en el canal: news-other
#
# Titular: Late actor Kader Khan conferred with Padma Shri
# Publicado en el canal: news-other
#
# Titular: Malayalam actress Manju denies campaigning for Congress
# Publicado en el canal: news-other
#
# Titular: 'Roma' actor may miss Oscars after US visa was denied thrice
# Publicado en el canal: news-selected
#
# Titular: Shami has been a revelation since Australia series: Manjrekar
# Publicado en el canal: news-other
#
# Titular: Yuvraj hits 1st fifty in competitive cricket since October 2018
# Publicado en el canal: news-other
#
# Titular: Saina Nehwal enters Indonesia Masters semi-finals
# Publicado en el canal: news-other
#
# Titular: If Priyanka trump card, why Cong played with joker: Paresh Rawal
# Publicado en el canal: news-other
#
# Titular: Bengaluru-based bike taxi app Rapido raises ₹52 crore
# Publicado en el canal: news-money
#
# Titular: Designed to last 90 days, NASA rover completes 15 years on Mars
# Publicado en el canal: news-other
#
# Titular: India's pluralism is its greatest strength: President Kovind
# Publicado en el canal: news-selected
#
# Titular: I&B Ministry increases ad rates for private TV channels
# Publicado en el canal: news-other
#
# Titular: Will encourage those who want to have four kids: Andhra CM
# Publicado en el canal: news-other
#
# Titular: 2019 LS polls 'once-in-a-century moment': President Kovind
# Publicado en el canal: news-other
#
# Titular: Sahitya Akademi winning writer Krishna Sobti passes away at 93
# Publicado en el canal: news-other
#
# Titular: Pranab Mukherjee, N Deshmukh and B Hazarika awarded Bharat Ratna
# Publicado en el canal: news-other
#
# Titular: SC sets up new 5-member bench to hear Ayodhya case on January 29
# Publicado en el canal: news-other
#
# Titular: Footballer's sister urges police to resume search for missing plane
# Publicado en el canal: news-other
#
# Titular: 35 yrs ago, it said hello: Tim Cook on Apple's Macintosh computer
# Publicado en el canal: news-other
#
# Titular: Earth's oldest rock found in Moon samples brought 48 years ago
# Publicado en el canal: news-other
#
# Titular: Doomsday Clock remains at 'two minutes to midnight' for 2019
# Publicado en el canal: news-other
#
# Titular: 15 of 500 crocodiles removed so far for seaplane to Statue of Unity
# Publicado en el canal: news-other
#
# Titular: Resolve issue through dialogue: India on Venezuela crisis
# Publicado en el canal: news-selected
#
# Titular: Calling wife prostitute grave provocation: SC clears woman of murder
# Publicado en el canal: news-other
#
# Titular: Woman kidnapped from outside beauty parlour hours before wedding
# Publicado en el canal: news-other
#
# Titular: 185 passengers fall sick on board Canada plane
# Publicado en el canal: news-other
#
# Titular: Sikhs in US to donate food, funds to federal workers amid shutdown
# Publicado en el canal: news-selected
#
# Titular: Remains of explorer who named Australia discovered in London
# Publicado en el canal: news-other
#
# Titular: Came back from India trip, amazed at the changes: Mark Mobius
# Publicado en el canal: news-selected
#
# Titular: I'm ready to make a legit gay love story: Karan Johar
# Publicado en el canal: news-other
#
# Titular: Boman Irani joins cast of Vivek Oberoi's PM Modi biopic
# Publicado en el canal: news-other
#
# Titular: Ranbir, Varun don't have as much energy as Ranveer: Karan
# Publicado en el canal: news-other
#
# Titular: Rohit Shetty is obliged to make 'Golmaal 5': Arshad Warsi
# Publicado en el canal: news-other
#
# Titular: McCullum helps Team Rugby beat Team Cricket in T20 match
# Publicado en el canal: news-other
#
# Titular: Wasim Jaffer 1st to score 1,000 runs in a Ranji season twice
# Publicado en el canal: news-other
#
# Titular: Ex-US Open singles winner wins Aus Open women's doubles title
# Publicado en el canal: news-selected
#
# Titular: 3rd umpires who don't do well will be weeded out: Saba Karim
# Publicado en el canal: news-other
#
# Titular: Will waive farm loans in 10 days if we win: Rahul in Odisha
# Publicado en el canal: news-other
#
# Titular: 855 police officers awarded medals on eve of Republic Day
# Publicado en el canal: news-other
# Titular: Jaitley in good health, recovering rapidly: Piyush Goyal
# Publicado en el canal: news-other
#
# Titular: 33-yr-old man rapes 3-yr-old girl in Hyderabad, arrested
# Publicado en el canal: news-other
#
# Titular: Groww has made investing commission free
# Publicado en el canal: news-other
#
# Titular: Sena workers protest inside movie hall over no 'Thackeray' poster
# Publicado en el canal: news-other
#
# Titular: Concepts like 'kanya daan' need to change: Screenplay writer Juhi
# Publicado en el canal: news-other
#
# Titular: Nawazuddin Siddiqui starrer 'Thackeray' hits the theatres
# Publicado en el canal: news-other
#
# Titular: Man asks for new Maps feature, Google India responds with shayari
# Publicado en el canal: news-selected
#
# Titular: We don't sell people's data: Facebook CEO Mark Zuckerberg
# Publicado en el canal: news-other
#
# Titular: When PM Modi abuses me, I feel like hugging him: Rahul
# Publicado en el canal: news-other
#
# Titular: IIT Delhi alumnus' lingerie brand Clovia raises $10 million
# Publicado en el canal: news-money
#
# Titular: Zomato hires psychiatrist to counsel delivery executives
# Publicado en el canal: news-other
#
# Titular: 19-year-old boy killed 20-year-old aspiring model for refusing sex
# Publicado en el canal: news-other
#
# Titular: Brazil 1st openly gay congressman quits, leaves country over threats
# Publicado en el canal: news-other
#
# Titular: Get a loan: US commerce chief to unpaid workers amid govt shutdown
# Publicado en el canal: news-selected
#
# Titular: Supreme Court upholds India's new insolvency law in its entirety
# Publicado en el canal: news-selected
#
# Titular: CBI may probe ICICI, Goldman India CEOs in Kochhar-Videocon case
# Publicado en el canal: news-selected
#
# Titular: Swara Bhasker to launch her production house Kahaaniwaaley
# Publicado en el canal: news-other
#
# Titular: To friendship, love, parenting: Kunal to Soha on anniversary
# Publicado en el canal: news-other
#
# Titular: Taking up risky roles has now become the norm: Tabu
# Publicado en el canal: news-other
#
# Titular: Women don't need to prove themselves to anyone: Shilpa Shetty
# Publicado en el canal: news-other
#
# Titular: Umesh picks 12 wkts as Vidarbha reach 2nd straight Ranji final
# Publicado en el canal: news-other
#
# Titular: Windies Women's captain refuses to go to Pak for T20I series
# Publicado en el canal: news-other
#
# Titular: MNF can leave NDA over Citizenship Bill: Mizoram CM
# Publicado en el canal: news-other
#
# Titular: RSS mother ship of BJP, wants to control institutions: Rahul
# Publicado en el canal: news-other
#
# Titular: Delhi Metro service to be partially curtailed on R-Day: DMRC
# Publicado en el canal: news-other
#
# Titular: Leopard injures 3 after entering crowded locality in Nashik
# Publicado en el canal: news-other
#
# Titular: Farm loan waiver of ₹10, ₹20 a cruel joke: Shivraj Chouhan
# Publicado en el canal: news-money
#
# Titular: Andhra teacher arrested for raping Class 2 girl in school
# Publicado en el canal: news-other
#
# Titular: US orders its staff to leave Venezuela amid political crisis
# Publicado en el canal: news-selected
